# %% [markdown]
# <a href="https://colab.research.google.com/github/kovzanok/dls-final-task/blob/main/1_dop_Identification_Rate_Metric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Identification Rate Metric

# %% [markdown]
# При обучении модели для распознавания лиц с помощью CE (кросс-энтропии) мы можем считать метрику accuracy как индикатор того, насколько хорошо наша модель работает. Но у accuracy тут есть недостаток: она не сможет померить, насколько хорошо наша модель работает на лицах людей, которых нет в обучающей выборке.
#
# Чтобы это исправить, придумали новую метрику: **identification rate**. Вот как она работает:
#
# Создадим два набора изображений лиц: query и distractors. Никакие лица из этих наборов не должны содержаться в обучающем и валидационном датасете.
#
# 1. посчитаем косинусные расстояния между лицами, соответствующими одним и тем же людям из query части. Например, пусть одному человеку соответствуют три фото в query: 01.jpg, 02.jpg, 03.jpg. Тогда считаем три косинусных расстояния между всеми тремя парами из этих фото.
# 2. посчитаем косинусные расстояния между лицами, соответствующими разным людям из query части.
# 3. посчитаем косинусные расстояния между всеми парами лиц из query и distractors. Т.е. пара — это (лицо из query, лицо из distractors). Всего получится |query|*|distractors| пар.
# 4. Сложим количества пар, полученных на 2 и 3 шагах. Это количество false пар.
# 5. Зафиксируем **FPR** (false positive rate). Пусть, например, будет 0.01. FPR, умноженный на количество false пар из шага 4 — это разрешенное количество false positives, которые мы разрешаем нашей модели. Обозначим это количество через N.
# 6. Отсортируем все значения косинусных расстояний false пар. N — ое по счету значение расстояния зафиксируем как **пороговое расстояние**.
# 7. Посчитаем количество positive пар с шага 1, которые имеют косинусное расстояние меньше, чем пороговое расстояние. Поделим это количество на общее количество positive пар с шага 1. Это будет TPR (true positive rate) — итоговое значение нашей метрики.
#
# Такая метрика обычно обозначается как TPR@FPR=0.01. FPR может быть разным. Приразных FPR будет получаться разное TPR.
#
# Смысл этой метрики в том, что мы фиксируем вероятность ошибки вида false positive, т.е. когда "сеть сказала, что это один и тот же человек, но это не так", считаем порог косинусного расстояния для этого значения ошибки, потом берем все positive пары и смотрим, у скольких из них расстояние меньше этого порога. Т.е. насколько точно наша сеть ищет похожие лица при заданной вероятности ошибки вида false positive.

# %% [markdown]
# **Для подсчета метрик, то вам нужно разбить данные на query и distractors самим.**
#
# Делается это примерно так:
# - Выбраете несколько id, которые не использовались при тренировке моделей, и помещаете их в query set;
# - Выбираете несколько id, которые не использовались при тренировке моделей и не входят в query, и помещаете их в distractors set. Обычно distractors set должен быть сильно больше, чем query set.
# - Обрабатываете картинки из query и distractors тем же способом, что картинки для обучения сети.
#
#
# Обратите внимание, что если картинок в query и distractors очень много, то полученных пар картинок в пунктах 1-2-3 алгоритма подсчета TPR@FPR будет очень-очень много. Чтобы код подсчета работал быстрее, ограничивайте размеры этих датасетов. Контролируйте, сколько значений расстояний вы считаете.
#
# Ниже дан шаблон кода для реализации FPR@TPR метрики и ячейки с тестами. Тесты проверяют, что ваш код в ячейках написан правильно.

# %% [markdown]
# ## План заданий

# %% [markdown]
# * Правильно разбить датасет на query и distractors
# * Реализовать метрику и пройти все тесты
# * Подгрузить все модели, обученные на разных лоссах и сравнить их метрики

# %%
import os
import cv2
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
from torch.nn import functional as F
from torch import nn
import torchvision.models as models
import torch
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

from itertools import combinations, chain
import math

# %% [markdown]
# Полный датасет CelebA

# %%
# !gdown 1HT72tZVCrXD0u_Ata8T1BaIMrz0rOcZn
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1HT72tZVCrXD0u_Ata8T1BaIMrz0rOcZn
# From (redirected): https://drive.google.com/uc?id=1HT72tZVCrXD0u_Ata8T1BaIMrz0rOcZn&confirm=t&uuid=22ffca30-9fdd-4f17-8c12-6b117c146756
# To: /content/img_align_celeba.zip
# 100% 1.44G/1.44G [00:22<00:00, 65.4MB/s]

# %%
# !unzip -q /content/img_align_celeba.zip -d /content/celeba/

# %% [markdown]
# Датасет, использованный для обучения модели

# %%
# !gdown 1bHLaSZ2frNjyK2hLTXTuPFlFRxfJDxwb
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1bHLaSZ2frNjyK2hLTXTuPFlFRxfJDxwb
# From (redirected): https://drive.google.com/uc?id=1bHLaSZ2frNjyK2hLTXTuPFlFRxfJDxwb&confirm=t&uuid=4ade69c0-8662-49c2-878c-dff2cc7fd62a
# To: /content/file.zip
# 100% 401M/401M [00:07<00:00, 54.0MB/s]

# %%
# !unzip /content/file.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/content/stage_3_dataset/112660.jpg
#   inflating: /content/content/stage_3_dataset/129052.jpg
#   inflating: /content/content/stage_3_dataset/151389.jpg
#   inflating: /content/content/stage_3_dataset/118111.jpg
#   inflating: /content/content/stage_3_dataset/000174.jpg
#   inflating: /content/content/stage_3_dataset/013829.jpg
#   inflating: /content/content/stage_3_dataset/107408.jpg
#   inflating: /content/content/stage_3_dataset/112157.jpg
#   inflating: /content/content/stage_3_dataset/119239.jpg
#   inflating: /content/content/stage_3_dataset/120061.jpg
#   inflating: /content/content/stage_3_dataset/147590.jpg
#   inflating: /content/content/stage_3_dataset/037708.jpg
#   inflating: /content/content/stage_3_dataset/072505.jpg
#   inflating: /content/content/stage_3_dataset/100668.jpg
#   inflating: /content/content/stage_3_dataset/118256.jpg
#   inflating: /content/content/stage_3_dataset/121771.jpg
#   inflating: /content/content/stage_3_dataset/107682.jpg
#   inflating: /content/content/stage_3_dataset/024742.jpg
#   inflating: /content/content/stage_3_dataset/106149.jpg
#   inflating: /content/content/stage_3_dataset/098302.jpg
#   inflating: /content/content/stage_3_dataset/095506.jpg
#   inflating: /content/content/stage_3_dataset/145869.jpg
#   inflating: /content/content/stage_3_dataset/144070.jpg
#   inflating: /content/content/stage_3_dataset/045228.jpg
#   inflating: /content/content/stage_3_dataset/051010.jpg
#   inflating: /content/content/stage_3_dataset/008536.jpg
#   inflating: /content/content/stage_3_dataset/128077.jpg
#   inflating: /content/content/stage_3_dataset/003607.jpg
#   inflating: /content/content/stage_3_dataset/076848.jpg
#   inflating: /content/content/stage_3_dataset/010834.jpg
#   inflating: /content/content/stage_3_dataset/049818.jpg
#   inflating: /content/content/stage_3_dataset/002060.jpg
#   inflating: /content/content/stage_3_dataset/004054.jpg
#   inflating: /content/content/stage_3_dataset/132898.jpg
#   inflating: /content/content/stage_3_dataset/042207.jpg
#   inflating: /content/content/stage_3_dataset/040769.jpg
#   inflating: /content/content/stage_3_dataset/042545.jpg
#   inflating: /content/content/stage_3_dataset/086627.jpg
#   inflating: /content/content/stage_3_dataset/136296.jpg
#   inflating: /content/content/stage_3_dataset/049836.jpg
#   inflating: /content/content/stage_3_dataset/019284.jpg
#   inflating: /content/content/stage_3_dataset/024959.jpg
#   inflating: /content/content/stage_3_dataset/104398.jpg
#   inflating: /content/content/stage_3_dataset/145988.jpg
#   inflating: /content/content/stage_3_dataset/127758.jpg
#   inflating: /content/content/stage_3_dataset/008063.jpg
#   inflating: /content/content/stage_3_dataset/004071.jpg
#   inflating: /content/content/stage_3_dataset/134804.jpg
#   inflating: /content/content/stage_3_dataset/086302.jpg
#   inflating: /content/content/stage_3_dataset/026598.jpg
#   inflating: /content/content/stage_3_dataset/096245.jpg
#   inflating: /content/content/stage_3_dataset/014998.jpg
#   inflating: /content/content/stage_3_dataset/029731.jpg
#   inflating: /content/content/stage_3_dataset/093428.jpg
#   inflating: /content/content/stage_3_dataset/093842.jpg
#   inflating: /content/content/stage_3_dataset/067815.jpg
#   inflating: /content/content/stage_3_dataset/140299.jpg
#   inflating: /content/content/stage_3_dataset/067276.jpg
#   inflating: /content/content/stage_3_dataset/115083.jpg
#   inflating: /content/content/stage_3_dataset/138564.jpg
#   inflating: /content/content/stage_3_dataset/077564.jpg
#   inflating: /content/content/stage_3_dataset/060532.jpg
#   inflating: /content/content/stage_3_dataset/044773.jpg
#   inflating: /content/content/stage_3_dataset/054817.jpg
#   inflating: /content/content/stage_3_dataset/034830.jpg
#   inflating: /content/content/stage_3_dataset/147551.jpg
#   inflating: /content/content/stage_3_dataset/139332.jpg
#   inflating: /content/content/stage_3_dataset/083964.jpg
#   inflating: /content/content/stage_3_dataset/150003.jpg
#   inflating: /content/content/stage_3_dataset/051243.jpg
#   inflating: /content/content/stage_3_dataset/086303.jpg
#   inflating: /content/content/stage_3_dataset/103743.jpg
#   inflating: /content/content/stage_3_dataset/134169.jpg
#   inflating: /content/content/stage_3_dataset/143361.jpg
#   inflating: /content/content/stage_3_dataset/084861.jpg
#   inflating: /content/content/stage_3_dataset/125354.jpg
#   inflating: /content/content/stage_3_dataset/039970.jpg
#   inflating: /content/content/stage_3_dataset/031070.jpg
#   inflating: /content/content/stage_3_dataset/110710.jpg
#   inflating: /content/content/stage_3_dataset/015132.jpg
#   inflating: /content/content/stage_3_dataset/027900.jpg
#   inflating: /content/content/stage_3_dataset/125489.jpg
#   inflating: /content/content/stage_3_dataset/019564.jpg
#   inflating: /content/content/stage_3_dataset/077768.jpg
#   inflating: /content/content/stage_3_dataset/118112.jpg
#   inflating: /content/content/stage_3_dataset/092471.jpg
#   inflating: /content/content/stage_3_dataset/009839.jpg
#   inflating: /content/content/stage_3_dataset/110472.jpg
#   inflating: /content/content/stage_3_dataset/081153.jpg
#   inflating: /content/content/stage_3_dataset/100421.jpg
#   inflating: /content/content/stage_3_dataset/140203.jpg
#   inflating: /content/content/stage_3_dataset/138717.jpg
#   inflating: /content/content/stage_3_dataset/141953.jpg
#   inflating: /content/content/stage_3_dataset/121392.jpg
#   inflating: /content/content/stage_3_dataset/028673.jpg
#   inflating: /content/content/stage_3_dataset/101423.jpg
#   inflating: /content/content/stage_3_dataset/125776.jpg
#   inflating: /content/content/stage_3_dataset/146951.jpg
#   inflating: /content/content/stage_3_dataset/146209.jpg
#   inflating: /content/content/stage_3_dataset/062683.jpg
#   inflating: /content/content/stage_3_dataset/077385.jpg
#   inflating: /content/content/stage_3_dataset/007668.jpg
#   inflating: /content/content/stage_3_dataset/020312.jpg
#   inflating: /content/content/stage_3_dataset/066037.jpg
#   inflating: /content/content/stage_3_dataset/137937.jpg
#   inflating: /content/content/stage_3_dataset/053464.jpg
#   inflating: /content/content/stage_3_dataset/013515.jpg
#   inflating: /content/content/stage_3_dataset/132114.jpg
#   inflating: /content/content/stage_3_dataset/139828.jpg
#   inflating: /content/content/stage_3_dataset/059456.jpg
#   inflating: /content/content/stage_3_dataset/036269.jpg
#   inflating: /content/content/stage_3_dataset/070015.jpg
#   inflating: /content/content/stage_3_dataset/092485.jpg
#   inflating: /content/content/stage_3_dataset/052088.jpg
#   inflating: /content/content/stage_3_dataset/068546.jpg
#   inflating: /content/content/stage_3_dataset/140935.jpg
#   inflating: /content/content/stage_3_dataset/069958.jpg
#   inflating: /content/content/stage_3_dataset/133070.jpg
#   inflating: /content/content/stage_3_dataset/026982.jpg
#   inflating: /content/content/stage_3_dataset/103110.jpg
#   inflating: /content/content/stage_3_dataset/003765.jpg
#   inflating: /content/content/stage_3_dataset/024722.jpg
#   inflating: /content/content/stage_3_dataset/109742.jpg
#   inflating: /content/content/stage_3_dataset/064509.jpg
#   inflating: /content/content/stage_3_dataset/092632.jpg
#   inflating: /content/content/stage_3_dataset/143856.jpg
#   inflating: /content/content/stage_3_dataset/043696.jpg
#   inflating: /content/content/stage_3_dataset/113168.jpg
#   inflating: /content/content/stage_3_dataset/101822.jpg
#   inflating: /content/content/stage_3_dataset/147080.jpg
#   inflating: /content/content/stage_3_dataset/147526.jpg
#   inflating: /content/content/stage_3_dataset/113103.jpg
#   inflating: /content/content/stage_3_dataset/052449.jpg
#   inflating: /content/content/stage_3_dataset/101920.jpg
#   inflating: /content/content/stage_3_dataset/073934.jpg
#   inflating: /content/content/stage_3_dataset/015402.jpg
#   inflating: /content/content/stage_3_dataset/075812.jpg
#   inflating: /content/content/stage_3_dataset/088132.jpg
#   inflating: /content/content/stage_3_dataset/096424.jpg
#   inflating: /content/content/stage_3_dataset/141790.jpg
#   inflating: /content/content/stage_3_dataset/130942.jpg
#   inflating: /content/content/stage_3_dataset/126384.jpg
#   inflating: /content/content/stage_3_dataset/038963.jpg
#   inflating: /content/content/stage_3_dataset/003417.jpg
#   inflating: /content/content/stage_3_dataset/145675.jpg
#   inflating: /content/content/stage_3_dataset/145858.jpg
#   inflating: /content/content/stage_3_dataset/071557.jpg
#   inflating: /content/content/stage_3_dataset/044130.jpg
#   inflating: /content/content/stage_3_dataset/081130.jpg
#   inflating: /content/content/stage_3_dataset/123024.jpg
#   inflating: /content/content/stage_3_dataset/018900.jpg
#   inflating: /content/content/stage_3_dataset/091760.jpg
#   inflating: /content/content/stage_3_dataset/077584.jpg
#   inflating: /content/content/stage_3_dataset/089492.jpg
#   inflating: /content/content/stage_3_dataset/091488.jpg
#   inflating: /content/content/stage_3_dataset/050479.jpg
#   inflating: /content/content/stage_3_dataset/112035.jpg
#   inflating: /content/content/stage_3_dataset/106742.jpg
#   inflating: /content/content/stage_3_dataset/034208.jpg
#   inflating: /content/content/stage_3_dataset/053473.jpg
#   inflating: /content/content/stage_3_dataset/128103.jpg
#   inflating: /content/content/stage_3_dataset/046353.jpg
#   inflating: /content/content/stage_3_dataset/046392.jpg
#   inflating: /content/content/stage_3_dataset/001644.jpg
#   inflating: /content/content/stage_3_dataset/070807.jpg
#   inflating: /content/content/stage_3_dataset/006798.jpg
#   inflating: /content/content/stage_3_dataset/060475.jpg
#   inflating: /content/content/stage_3_dataset/031042.jpg
#   inflating: /content/content/stage_3_dataset/139459.jpg
#   inflating: /content/content/stage_3_dataset/130093.jpg
#   inflating: /content/content/stage_3_dataset/011152.jpg
#   inflating: /content/content/stage_3_dataset/028309.jpg
#   inflating: /content/content/stage_3_dataset/031381.jpg
#   inflating: /content/content/stage_3_dataset/052481.jpg
#   inflating: /content/content/stage_3_dataset/017432.jpg
#   inflating: /content/content/stage_3_dataset/144271.jpg
#   inflating: /content/content/stage_3_dataset/040691.jpg
#   inflating: /content/content/stage_3_dataset/069732.jpg
#   inflating: /content/content/stage_3_dataset/099222.jpg
#   inflating: /content/content/stage_3_dataset/032535.jpg
#   inflating: /content/content/stage_3_dataset/057526.jpg
#   inflating: /content/content/stage_3_dataset/040733.jpg
#   inflating: /content/content/stage_3_dataset/008960.jpg
#   inflating: /content/content/stage_3_dataset/100146.jpg
#   inflating: /content/content/stage_3_dataset/063524.jpg
#   inflating: /content/content/stage_3_dataset/051276.jpg
#   inflating: /content/content/stage_3_dataset/150690.jpg
#   inflating: /content/content/stage_3_dataset/053004.jpg
#   inflating: /content/content/stage_3_dataset/027762.jpg
#   inflating: /content/content/stage_3_dataset/020635.jpg
#   inflating: /content/content/stage_3_dataset/017699.jpg
#   inflating: /content/content/stage_3_dataset/140242.jpg
#   inflating: /content/content/stage_3_dataset/064601.jpg
#   inflating: /content/content/stage_3_dataset/054774.jpg
#   inflating: /content/content/stage_3_dataset/091163.jpg
#   inflating: /content/content/stage_3_dataset/011259.jpg
#   inflating: /content/content/stage_3_dataset/067857.jpg
#   inflating: /content/content/stage_3_dataset/094495.jpg
#   inflating: /content/content/stage_3_dataset/112597.jpg
#   inflating: /content/content/stage_3_dataset/127337.jpg
#   inflating: /content/content/stage_3_dataset/128149.jpg
#   inflating: /content/content/stage_3_dataset/010267.jpg
#   inflating: /content/content/stage_3_dataset/131907.jpg
#   inflating: /content/content/stage_3_dataset/095764.jpg
#   inflating: /content/content/stage_3_dataset/114270.jpg
#   inflating: /content/content/stage_3_dataset/115718.jpg
#   inflating: /content/content/stage_3_dataset/015144.jpg
#   inflating: /content/content/stage_3_dataset/070013.jpg
#   inflating: /content/content/stage_3_dataset/009513.jpg
#   inflating: /content/content/stage_3_dataset/081253.jpg
#   inflating: /content/content/stage_3_dataset/064143.jpg
#   inflating: /content/content/stage_3_dataset/150783.jpg
#   inflating: /content/content/stage_3_dataset/095837.jpg
#   inflating: /content/content/stage_3_dataset/050766.jpg
#   inflating: /content/content/stage_3_dataset/058093.jpg
#   inflating: /content/content/stage_3_dataset/116319.jpg
#   inflating: /content/content/stage_3_dataset/021222.jpg
#   inflating: /content/content/stage_3_dataset/144640.jpg
#   inflating: /content/content/stage_3_dataset/002860.jpg
#   inflating: /content/content/stage_3_dataset/037743.jpg
#   inflating: /content/content/stage_3_dataset/079627.jpg
#   inflating: /content/content/stage_3_dataset/027022.jpg
#   inflating: /content/content/stage_3_dataset/150949.jpg
#   inflating: /content/content/stage_3_dataset/035189.jpg
#   inflating: /content/content/stage_3_dataset/089855.jpg
#   inflating: /content/content/stage_3_dataset/034647.jpg
#   inflating: /content/content/stage_3_dataset/000206.jpg
#   inflating: /content/content/stage_3_dataset/076496.jpg
#   inflating: /content/content/stage_3_dataset/114017.jpg
#   inflating: /content/content/stage_3_dataset/017828.jpg
#   inflating: /content/content/stage_3_dataset/022937.jpg
#   inflating: /content/content/stage_3_dataset/001749.jpg
#   inflating: /content/content/stage_3_dataset/117095.jpg
#   inflating: /content/content/stage_3_dataset/064247.jpg
#   inflating: /content/content/stage_3_dataset/088311.jpg
#   inflating: /content/content/stage_3_dataset/035111.jpg
#   inflating: /content/content/stage_3_dataset/116978.jpg
#   inflating: /content/content/stage_3_dataset/095509.jpg
#   inflating: /content/content/stage_3_dataset/097856.jpg
#   inflating: /content/content/stage_3_dataset/043559.jpg
#   inflating: /content/content/stage_3_dataset/031140.jpg
#   inflating: /content/content/stage_3_dataset/017655.jpg
#   inflating: /content/content/stage_3_dataset/145957.jpg
#   inflating: /content/content/stage_3_dataset/137993.jpg
#   inflating: /content/content/stage_3_dataset/060478.jpg
#   inflating: /content/content/stage_3_dataset/089420.jpg
#   inflating: /content/content/stage_3_dataset/088747.jpg
#   inflating: /content/content/stage_3_dataset/065216.jpg
#   inflating: /content/content/stage_3_dataset/108737.jpg
#   inflating: /content/content/stage_3_dataset/028105.jpg
#   inflating: /content/content/stage_3_dataset/078418.jpg
#   inflating: /content/content/stage_3_dataset/087456.jpg
#   inflating: /content/content/stage_3_dataset/110087.jpg
#   inflating: /content/content/stage_3_dataset/036584.jpg
#   inflating: /content/content/stage_3_dataset/039744.jpg
#   inflating: /content/content/stage_3_dataset/048839.jpg
#   inflating: /content/content/stage_3_dataset/140017.jpg
#   inflating: /content/content/stage_3_dataset/122384.jpg
#   inflating: /content/content/stage_3_dataset/062520.jpg
#   inflating: /content/content/stage_3_dataset/133878.jpg
#   inflating: /content/content/stage_3_dataset/018220.jpg
#   inflating: /content/content/stage_3_dataset/014700.jpg
#   inflating: /content/content/stage_3_dataset/025878.jpg
#   inflating: /content/content/stage_3_dataset/080751.jpg
#   inflating: /content/content/stage_3_dataset/002963.jpg
#   inflating: /content/content/stage_3_dataset/055051.jpg
#   inflating: /content/content/stage_3_dataset/030548.jpg
#   inflating: /content/content/stage_3_dataset/004640.jpg
#   inflating: /content/content/stage_3_dataset/097023.jpg
#   inflating: /content/content/stage_3_dataset/111992.jpg
#   inflating: /content/content/stage_3_dataset/046322.jpg
#   inflating: /content/content/stage_3_dataset/017500.jpg
#   inflating: /content/content/stage_3_dataset/145496.jpg
#   inflating: /content/content/stage_3_dataset/059164.jpg
#   inflating: /content/content/stage_3_dataset/102092.jpg
#   inflating: /content/content/stage_3_dataset/118777.jpg
#   inflating: /content/content/stage_3_dataset/130601.jpg
#   inflating: /content/content/stage_3_dataset/060893.jpg
#   inflating: /content/content/stage_3_dataset/030409.jpg
#   inflating: /content/content/stage_3_dataset/112613.jpg
#   inflating: /content/content/stage_3_dataset/088256.jpg
#   inflating: /content/content/stage_3_dataset/095291.jpg
#   inflating: /content/content/stage_3_dataset/151366.jpg
#   inflating: /content/content/stage_3_dataset/010699.jpg
#   inflating: /content/content/stage_3_dataset/145691.jpg
#   inflating: /content/content/stage_3_dataset/144977.jpg
#   inflating: /content/content/stage_3_dataset/088559.jpg
#   inflating: /content/content/stage_3_dataset/030189.jpg
#   inflating: /content/content/stage_3_dataset/133973.jpg
#   inflating: /content/content/stage_3_dataset/034971.jpg
#   inflating: /content/content/stage_3_dataset/070397.jpg
#   inflating: /content/content/stage_3_dataset/058723.jpg
#   inflating: /content/content/stage_3_dataset/036294.jpg
#   inflating: /content/content/stage_3_dataset/022131.jpg
#   inflating: /content/content/stage_3_dataset/007756.jpg
#   inflating: /content/content/stage_3_dataset/007329.jpg
#   inflating: /content/content/stage_3_dataset/125243.jpg
#   inflating: /content/content/stage_3_dataset/034722.jpg
#   inflating: /content/content/stage_3_dataset/143290.jpg
#   inflating: /content/content/stage_3_dataset/065896.jpg
#   inflating: /content/content/stage_3_dataset/106974.jpg
#   inflating: /content/content/stage_3_dataset/128867.jpg
#   inflating: /content/content/stage_3_dataset/085713.jpg
#   inflating: /content/content/stage_3_dataset/014098.jpg
#   inflating: /content/content/stage_3_dataset/140745.jpg
#   inflating: /content/content/stage_3_dataset/070883.jpg
#   inflating: /content/content/stage_3_dataset/128565.jpg
#   inflating: /content/content/stage_3_dataset/128496.jpg
#   inflating: /content/content/stage_3_dataset/131177.jpg
#   inflating: /content/content/stage_3_dataset/044868.jpg
#   inflating: /content/content/stage_3_dataset/111159.jpg
#   inflating: /content/content/stage_3_dataset/028492.jpg
#   inflating: /content/content/stage_3_dataset/080368.jpg
#   inflating: /content/content/stage_3_dataset/098162.jpg
#   inflating: /content/content/stage_3_dataset/127051.jpg
#   inflating: /content/content/stage_3_dataset/125609.jpg
#   inflating: /content/content/stage_3_dataset/078642.jpg
#   inflating: /content/content/stage_3_dataset/078851.jpg
#   inflating: /content/content/stage_3_dataset/037976.jpg
#   inflating: /content/content/stage_3_dataset/034964.jpg
#   inflating: /content/content/stage_3_dataset/149134.jpg
#   inflating: /content/content/stage_3_dataset/048192.jpg
#   inflating: /content/content/stage_3_dataset/057071.jpg
#   inflating: /content/content/stage_3_dataset/100173.jpg
#   inflating: /content/content/stage_3_dataset/021776.jpg
#   inflating: /content/content/stage_3_dataset/027997.jpg
#   inflating: /content/content/stage_3_dataset/108998.jpg
#   inflating: /content/content/stage_3_dataset/132007.jpg
#   inflating: /content/content/stage_3_dataset/064489.jpg
#   inflating: /content/content/stage_3_dataset/141503.jpg
#   inflating: /content/content/stage_3_dataset/019194.jpg
#   inflating: /content/content/stage_3_dataset/088648.jpg
#   inflating: /content/content/stage_3_dataset/057963.jpg
#   inflating: /content/content/stage_3_dataset/063194.jpg
#   inflating: /content/content/stage_3_dataset/082625.jpg
#   inflating: /content/content/stage_3_dataset/019269.jpg
#   inflating: /content/content/stage_3_dataset/070482.jpg
#   inflating: /content/content/stage_3_dataset/069004.jpg
#   inflating: /content/content/stage_3_dataset/111287.jpg
#   inflating: /content/content/stage_3_dataset/105869.jpg
#   inflating: /content/content/stage_3_dataset/129675.jpg
#   inflating: /content/content/stage_3_dataset/036582.jpg
#   inflating: /content/content/stage_3_dataset/017949.jpg
#   inflating: /content/content/stage_3_dataset/147768.jpg
#   inflating: /content/content/stage_3_dataset/007552.jpg
#   inflating: /content/content/stage_3_dataset/085279.jpg
#   inflating: /content/content/stage_3_dataset/081454.jpg
#   inflating: /content/content/stage_3_dataset/149745.jpg
#   inflating: /content/content/stage_3_dataset/017549.jpg
#   inflating: /content/content/stage_3_dataset/105490.jpg
#   inflating: /content/content/stage_3_dataset/137018.jpg
#   inflating: /content/content/stage_3_dataset/075742.jpg
#   inflating: /content/content/stage_3_dataset/043497.jpg
#   inflating: /content/content/stage_3_dataset/005510.jpg
#   inflating: /content/content/stage_3_dataset/010266.jpg
#   inflating: /content/content/stage_3_dataset/001909.jpg
#   inflating: /content/content/stage_3_dataset/109715.jpg
#   inflating: /content/content/stage_3_dataset/111692.jpg
#   inflating: /content/content/stage_3_dataset/146255.jpg
#   inflating: /content/content/stage_3_dataset/060525.jpg
#   inflating: /content/content/stage_3_dataset/094439.jpg
#   inflating: /content/content/stage_3_dataset/122422.jpg
#   inflating: /content/content/stage_3_dataset/037497.jpg
#   inflating: /content/content/stage_3_dataset/006790.jpg
#   inflating: /content/content/stage_3_dataset/129061.jpg
#   inflating: /content/content/stage_3_dataset/128853.jpg
#   inflating: /content/content/stage_3_dataset/128758.jpg
#   inflating: /content/content/stage_3_dataset/038803.jpg
#   inflating: /content/content/stage_3_dataset/082358.jpg
#   inflating: /content/content/stage_3_dataset/025440.jpg
#   inflating: /content/content/stage_3_dataset/012176.jpg
#   inflating: /content/content/stage_3_dataset/048268.jpg
#   inflating: /content/content/stage_3_dataset/052687.jpg
#   inflating: /content/content/stage_3_dataset/094283.jpg
#   inflating: /content/content/stage_3_dataset/129974.jpg
#   inflating: /content/content/stage_3_dataset/109037.jpg
#   inflating: /content/content/stage_3_dataset/052425.jpg
#   inflating: /content/content/stage_3_dataset/026316.jpg
#   inflating: /content/content/stage_3_dataset/100443.jpg
#   inflating: /content/content/stage_3_dataset/140529.jpg
#   inflating: /content/content/stage_3_dataset/131798.jpg
#   inflating: /content/content/stage_3_dataset/063772.jpg
#   inflating: /content/content/stage_3_dataset/149027.jpg
#   inflating: /content/content/stage_3_dataset/041953.jpg
#   inflating: /content/content/stage_3_dataset/081799.jpg
#   inflating: /content/content/stage_3_dataset/111326.jpg
#   inflating: /content/content/stage_3_dataset/144916.jpg
#   inflating: /content/content/stage_3_dataset/132062.jpg
#   inflating: /content/content/stage_3_dataset/096008.jpg
#   inflating: /content/content/stage_3_dataset/009169.jpg
#   inflating: /content/content/stage_3_dataset/148893.jpg
#   inflating: /content/content/stage_3_dataset/019629.jpg
#   inflating: /content/content/stage_3_dataset/095743.jpg
#   inflating: /content/content/stage_3_dataset/052397.jpg
#   inflating: /content/content/stage_3_dataset/019719.jpg
#   inflating: /content/content/stage_3_dataset/080962.jpg
#   inflating: /content/content/stage_3_dataset/022177.jpg
#   inflating: /content/content/stage_3_dataset/083198.jpg
#   inflating: /content/content/stage_3_dataset/112914.jpg
#   inflating: /content/content/stage_3_dataset/082468.jpg
#   inflating: /content/content/stage_3_dataset/106691.jpg
#   inflating: /content/content/stage_3_dataset/034220.jpg
#   inflating: /content/content/stage_3_dataset/093833.jpg
#   inflating: /content/content/stage_3_dataset/122439.jpg
#   inflating: /content/content/stage_3_dataset/005753.jpg
#   inflating: /content/content/stage_3_dataset/091771.jpg
#   inflating: /content/content/stage_3_dataset/151657.jpg
#   inflating: /content/content/stage_3_dataset/015129.jpg
#   inflating: /content/content/stage_3_dataset/130841.jpg
#   inflating: /content/content/stage_3_dataset/134237.jpg
#   inflating: /content/content/stage_3_dataset/057450.jpg
#   inflating: /content/content/stage_3_dataset/149892.jpg
#   inflating: /content/content/stage_3_dataset/141502.jpg
#   inflating: /content/content/stage_3_dataset/139079.jpg
#   inflating: /content/content/stage_3_dataset/017321.jpg
#   inflating: /content/content/stage_3_dataset/089892.jpg
#   inflating: /content/content/stage_3_dataset/034831.jpg
#   inflating: /content/content/stage_3_dataset/117787.jpg
#   inflating: /content/content/stage_3_dataset/039050.jpg
#   inflating: /content/content/stage_3_dataset/125101.jpg
#   inflating: /content/content/stage_3_dataset/043760.jpg
#   inflating: /content/content/stage_3_dataset/097711.jpg
#   inflating: /content/content/stage_3_dataset/117071.jpg
#   inflating: /content/content/stage_3_dataset/032777.jpg
#   inflating: /content/content/stage_3_dataset/066213.jpg
#   inflating: /content/content/stage_3_dataset/127119.jpg
#   inflating: /content/content/stage_3_dataset/110706.jpg
#   inflating: /content/content/stage_3_dataset/112890.jpg
#   inflating: /content/content/stage_3_dataset/142282.jpg
#   inflating: /content/content/stage_3_dataset/114962.jpg
#   inflating: /content/content/stage_3_dataset/084125.jpg
#   inflating: /content/content/stage_3_dataset/081244.jpg
#   inflating: /content/content/stage_3_dataset/100908.jpg
#   inflating: /content/content/stage_3_dataset/088574.jpg
#   inflating: /content/content/stage_3_dataset/123612.jpg
#   inflating: /content/content/stage_3_dataset/128917.jpg
#   inflating: /content/content/stage_3_dataset/038102.jpg
#   inflating: /content/content/stage_3_dataset/138659.jpg
#   inflating: /content/content/stage_3_dataset/145711.jpg
#   inflating: /content/content/stage_3_dataset/150879.jpg
#   inflating: /content/content/stage_3_dataset/134258.jpg
#   inflating: /content/content/stage_3_dataset/125057.jpg
#   inflating: /content/content/stage_3_dataset/086933.jpg
#   inflating: /content/content/stage_3_dataset/100411.jpg
#   inflating: /content/content/stage_3_dataset/112716.jpg
#   inflating: /content/content/stage_3_dataset/110635.jpg
#   inflating: /content/content/stage_3_dataset/052747.jpg
#   inflating: /content/content/stage_3_dataset/008848.jpg
#   inflating: /content/content/stage_3_dataset/101599.jpg
#   inflating: /content/content/stage_3_dataset/070604.jpg
#   inflating: /content/content/stage_3_dataset/056658.jpg
#   inflating: /content/content/stage_3_dataset/038917.jpg
#   inflating: /content/content/stage_3_dataset/073633.jpg
#   inflating: /content/content/stage_3_dataset/040885.jpg
#   inflating: /content/content/stage_3_dataset/109127.jpg
#   inflating: /content/content/stage_3_dataset/054652.jpg
#   inflating: /content/content/stage_3_dataset/128863.jpg
#   inflating: /content/content/stage_3_dataset/024374.jpg
#   inflating: /content/content/stage_3_dataset/147503.jpg
#   inflating: /content/content/stage_3_dataset/004182.jpg
#   inflating: /content/content/stage_3_dataset/066573.jpg
#   inflating: /content/content/stage_3_dataset/081077.jpg
#   inflating: /content/content/stage_3_dataset/141480.jpg
#   inflating: /content/content/stage_3_dataset/137418.jpg
#   inflating: /content/content/stage_3_dataset/135695.jpg
#   inflating: /content/content/stage_3_dataset/098948.jpg
#   inflating: /content/content/stage_3_dataset/120386.jpg
#   inflating: /content/content/stage_3_dataset/084602.jpg
#   inflating: /content/content/stage_3_dataset/136808.jpg
#   inflating: /content/content/stage_3_dataset/151010.jpg
#   inflating: /content/content/stage_3_dataset/145084.jpg
#   inflating: /content/content/stage_3_dataset/097501.jpg
#   inflating: /content/content/stage_3_dataset/147592.jpg
#   inflating: /content/content/stage_3_dataset/141730.jpg
#   inflating: /content/content/stage_3_dataset/056216.jpg
#   inflating: /content/content/stage_3_dataset/130073.jpg
#   inflating: /content/content/stage_3_dataset/056448.jpg
#   inflating: /content/content/stage_3_dataset/128284.jpg
#   inflating: /content/content/stage_3_dataset/009001.jpg
#   inflating: /content/content/stage_3_dataset/011344.jpg
#   inflating: /content/content/stage_3_dataset/149215.jpg
#   inflating: /content/content/stage_3_dataset/060324.jpg
#   inflating: /content/content/stage_3_dataset/041644.jpg
#   inflating: /content/content/stage_3_dataset/139385.jpg
#   inflating: /content/content/stage_3_dataset/104193.jpg
#   inflating: /content/content/stage_3_dataset/070336.jpg
#   inflating: /content/content/stage_3_dataset/053529.jpg
#   inflating: /content/content/stage_3_dataset/040508.jpg
#   inflating: /content/content/stage_3_dataset/070600.jpg
#   inflating: /content/content/stage_3_dataset/092296.jpg
#   inflating: /content/content/stage_3_dataset/127650.jpg
#   inflating: /content/content/stage_3_dataset/056377.jpg
#   inflating: /content/content/stage_3_dataset/042546.jpg
#   inflating: /content/content/stage_3_dataset/065371.jpg
#   inflating: /content/content/stage_3_dataset/126022.jpg
#   inflating: /content/content/stage_3_dataset/025675.jpg
#   inflating: /content/content/stage_3_dataset/054144.jpg
#   inflating: /content/content/stage_3_dataset/007925.jpg
#   inflating: /content/content/stage_3_dataset/138546.jpg
#   inflating: /content/content/stage_3_dataset/032542.jpg
#   inflating: /content/content/stage_3_dataset/145714.jpg
#   inflating: /content/content/stage_3_dataset/036580.jpg
#   inflating: /content/content/stage_3_dataset/077261.jpg
#   inflating: /content/content/stage_3_dataset/118021.jpg
#   inflating: /content/content/stage_3_dataset/146745.jpg
#   inflating: /content/content/stage_3_dataset/103165.jpg
#   inflating: /content/content/stage_3_dataset/073055.jpg
#   inflating: /content/content/stage_3_dataset/098400.jpg
#   inflating: /content/content/stage_3_dataset/071064.jpg
#   inflating: /content/content/stage_3_dataset/131240.jpg
#   inflating: /content/content/stage_3_dataset/109672.jpg
#   inflating: /content/content/stage_3_dataset/104778.jpg
#   inflating: /content/content/stage_3_dataset/037399.jpg
#   inflating: /content/content/stage_3_dataset/059521.jpg
#   inflating: /content/content/stage_3_dataset/083841.jpg
#   inflating: /content/content/stage_3_dataset/146126.jpg
#   inflating: /content/content/stage_3_dataset/073621.jpg
#   inflating: /content/content/stage_3_dataset/135855.jpg
#   inflating: /content/content/stage_3_dataset/138563.jpg
#   inflating: /content/content/stage_3_dataset/080076.jpg
#   inflating: /content/content/stage_3_dataset/078140.jpg
#   inflating: /content/content/stage_3_dataset/031922.jpg
#   inflating: /content/content/stage_3_dataset/060207.jpg
#   inflating: /content/content/stage_3_dataset/149461.jpg
#   inflating: /content/content/stage_3_dataset/022182.jpg
#   inflating: /content/content/stage_3_dataset/133193.jpg
#   inflating: /content/content/stage_3_dataset/031995.jpg
#   inflating: /content/content/stage_3_dataset/084500.jpg
#   inflating: /content/content/stage_3_dataset/022114.jpg
#   inflating: /content/content/stage_3_dataset/026118.jpg
#   inflating: /content/content/stage_3_dataset/110663.jpg
#   inflating: /content/content/stage_3_dataset/108342.jpg
#   inflating: /content/content/stage_3_dataset/038080.jpg
#   inflating: /content/content/stage_3_dataset/073596.jpg
#   inflating: /content/content/stage_3_dataset/024639.jpg
#   inflating: /content/content/stage_3_dataset/067509.jpg
#   inflating: /content/content/stage_3_dataset/025225.jpg
#   inflating: /content/content/stage_3_dataset/039944.jpg
#   inflating: /content/content/stage_3_dataset/010178.jpg
#   inflating: /content/content/stage_3_dataset/060098.jpg
#   inflating: /content/content/stage_3_dataset/121264.jpg
#   inflating: /content/content/stage_3_dataset/107802.jpg
#   inflating: /content/content/stage_3_dataset/013535.jpg
#   inflating: /content/content/stage_3_dataset/108145.jpg
#   inflating: /content/content/stage_3_dataset/090545.jpg
#   inflating: /content/content/stage_3_dataset/017030.jpg
#   inflating: /content/content/stage_3_dataset/006274.jpg
#   inflating: /content/content/stage_3_dataset/111951.jpg
#   inflating: /content/content/stage_3_dataset/125149.jpg
#   inflating: /content/content/stage_3_dataset/115185.jpg
#   inflating: /content/content/stage_3_dataset/052679.jpg
#   inflating: /content/content/stage_3_dataset/067550.jpg
#   inflating: /content/content/stage_3_dataset/063930.jpg
#   inflating: /content/content/stage_3_dataset/129188.jpg
#   inflating: /content/content/stage_3_dataset/107858.jpg
#   inflating: /content/content/stage_3_dataset/117369.jpg
#   inflating: /content/content/stage_3_dataset/122693.jpg
#   inflating: /content/content/stage_3_dataset/086097.jpg
#   inflating: /content/content/stage_3_dataset/137740.jpg
#   inflating: /content/content/stage_3_dataset/113177.jpg
#   inflating: /content/content/stage_3_dataset/116659.jpg
#   inflating: /content/content/stage_3_dataset/075873.jpg
#   inflating: /content/content/stage_3_dataset/003191.jpg
#   inflating: /content/content/stage_3_dataset/050408.jpg
#   inflating: /content/content/stage_3_dataset/132129.jpg
#   inflating: /content/content/stage_3_dataset/102230.jpg
#   inflating: /content/content/stage_3_dataset/123628.jpg
#   inflating: /content/content/stage_3_dataset/115878.jpg
#   inflating: /content/content/stage_3_dataset/059925.jpg
#   inflating: /content/content/stage_3_dataset/131852.jpg
#   inflating: /content/content/stage_3_dataset/017798.jpg
#   inflating: /content/content/stage_3_dataset/095804.jpg
#   inflating: /content/content/stage_3_dataset/035749.jpg
#   inflating: /content/content/stage_3_dataset/074334.jpg
#   inflating: /content/content/stage_3_dataset/031217.jpg
#   inflating: /content/content/stage_3_dataset/109238.jpg
#   inflating: /content/content/stage_3_dataset/006683.jpg
#   inflating: /content/content/stage_3_dataset/118101.jpg
#   inflating: /content/content/stage_3_dataset/002867.jpg
#   inflating: /content/content/stage_3_dataset/016900.jpg
#   inflating: /content/content/stage_3_dataset/150964.jpg
#   inflating: /content/content/stage_3_dataset/134883.jpg
#   inflating: /content/content/stage_3_dataset/014719.jpg
#   inflating: /content/content/stage_3_dataset/054838.jpg
#   inflating: /content/content/stage_3_dataset/081631.jpg
#   inflating: /content/content/stage_3_dataset/096182.jpg
#   inflating: /content/content/stage_3_dataset/144264.jpg
#   inflating: /content/content/stage_3_dataset/078612.jpg
#   inflating: /content/content/stage_3_dataset/048952.jpg
#   inflating: /content/content/stage_3_dataset/077503.jpg
#   inflating: /content/content/stage_3_dataset/015547.jpg
#   inflating: /content/content/stage_3_dataset/128261.jpg
#   inflating: /content/content/stage_3_dataset/125064.jpg
#   inflating: /content/content/stage_3_dataset/078693.jpg
#   inflating: /content/content/stage_3_dataset/032011.jpg
#   inflating: /content/content/stage_3_dataset/059001.jpg
#   inflating: /content/content/stage_3_dataset/086384.jpg
#   inflating: /content/content/stage_3_dataset/134972.jpg
#   inflating: /content/content/stage_3_dataset/126131.jpg
#   inflating: /content/content/stage_3_dataset/026432.jpg
#   inflating: /content/content/stage_3_dataset/100235.jpg
#   inflating: /content/content/stage_3_dataset/140859.jpg
#   inflating: /content/content/stage_3_dataset/075256.jpg
#   inflating: /content/content/stage_3_dataset/027465.jpg
#   inflating: /content/content/stage_3_dataset/037903.jpg
#   inflating: /content/content/stage_3_dataset/076162.jpg
#   inflating: /content/content/stage_3_dataset/023215.jpg
#   inflating: /content/content/stage_3_dataset/048654.jpg
#   inflating: /content/content/stage_3_dataset/003640.jpg
#   inflating: /content/content/stage_3_dataset/025788.jpg
#   inflating: /content/content/stage_3_dataset/121691.jpg
#   inflating: /content/content/stage_3_dataset/004781.jpg
#   inflating: /content/content/stage_3_dataset/124481.jpg
#   inflating: /content/content/stage_3_dataset/055374.jpg
#   inflating: /content/content/stage_3_dataset/052178.jpg
#   inflating: /content/content/stage_3_dataset/073698.jpg
#   inflating: /content/content/stage_3_dataset/079506.jpg
#   inflating: /content/content/stage_3_dataset/122185.jpg
#   inflating: /content/content/stage_3_dataset/147275.jpg
#   inflating: /content/content/stage_3_dataset/012434.jpg
#   inflating: /content/content/stage_3_dataset/036515.jpg
#   inflating: /content/content/stage_3_dataset/115740.jpg
#   inflating: /content/content/stage_3_dataset/023358.jpg
#   inflating: /content/content/stage_3_dataset/140677.jpg
#   inflating: /content/content/stage_3_dataset/053982.jpg
#   inflating: /content/content/stage_3_dataset/029711.jpg
#   inflating: /content/content/stage_3_dataset/115243.jpg
#   inflating: /content/content/stage_3_dataset/076044.jpg
#   inflating: /content/content/stage_3_dataset/076370.jpg
#   inflating: /content/content/stage_3_dataset/033713.jpg
#   inflating: /content/content/stage_3_dataset/092466.jpg
#   inflating: /content/content/stage_3_dataset/137153.jpg
#   inflating: /content/content/stage_3_dataset/038210.jpg
#   inflating: /content/content/stage_3_dataset/151670.jpg
#   inflating: /content/content/stage_3_dataset/129522.jpg
#   inflating: /content/content/stage_3_dataset/093994.jpg
#   inflating: /content/content/stage_3_dataset/071788.jpg
#   inflating: /content/content/stage_3_dataset/077519.jpg
#   inflating: /content/content/stage_3_dataset/090213.jpg
#   inflating: /content/content/stage_3_dataset/132455.jpg
#   inflating: /content/content/stage_3_dataset/020563.jpg
#   inflating: /content/content/stage_3_dataset/042964.jpg
#   inflating: /content/content/stage_3_dataset/104416.jpg
#   inflating: /content/content/stage_3_dataset/015822.jpg
#   inflating: /content/content/stage_3_dataset/049347.jpg
#   inflating: /content/content/stage_3_dataset/047068.jpg
#   inflating: /content/content/stage_3_dataset/074394.jpg
#   inflating: /content/content/stage_3_dataset/036637.jpg
#   inflating: /content/content/stage_3_dataset/109661.jpg
#   inflating: /content/content/stage_3_dataset/115098.jpg
#   inflating: /content/content/stage_3_dataset/007048.jpg
#   inflating: /content/content/stage_3_dataset/114990.jpg
#   inflating: /content/content/stage_3_dataset/024878.jpg
#   inflating: /content/content/stage_3_dataset/139265.jpg
#   inflating: /content/content/stage_3_dataset/054369.jpg
#   inflating: /content/content/stage_3_dataset/083598.jpg
#   inflating: /content/content/stage_3_dataset/019592.jpg
#   inflating: /content/content/stage_3_dataset/123543.jpg
#   inflating: /content/content/stage_3_dataset/056130.jpg
#   inflating: /content/content/stage_3_dataset/147033.jpg
#   inflating: /content/content/stage_3_dataset/022983.jpg
#   inflating: /content/content/stage_3_dataset/033857.jpg
#   inflating: /content/content/stage_3_dataset/027777.jpg
#   inflating: /content/content/stage_3_dataset/012886.jpg
#   inflating: /content/content/stage_3_dataset/024178.jpg
#   inflating: /content/content/stage_3_dataset/054211.jpg
#   inflating: /content/content/stage_3_dataset/064927.jpg
#   inflating: /content/content/stage_3_dataset/045518.jpg
#   inflating: /content/content/stage_3_dataset/137229.jpg
#   inflating: /content/content/stage_3_dataset/052105.jpg
#   inflating: /content/content/stage_3_dataset/050052.jpg
#   inflating: /content/content/stage_3_dataset/104062.jpg
#   inflating: /content/content/stage_3_dataset/057441.jpg
#   inflating: /content/content/stage_3_dataset/075837.jpg
#   inflating: /content/content/stage_3_dataset/010887.jpg
#   inflating: /content/content/stage_3_dataset/126592.jpg
#   inflating: /content/content/stage_3_dataset/056864.jpg
#   inflating: /content/content/stage_3_dataset/140089.jpg
#   inflating: /content/content/stage_3_dataset/006127.jpg
#   inflating: /content/content/stage_3_dataset/136131.jpg
#   inflating: /content/content/stage_3_dataset/037161.jpg
#   inflating: /content/content/stage_3_dataset/030121.jpg
#   inflating: /content/content/stage_3_dataset/083676.jpg
#   inflating: /content/content/stage_3_dataset/111239.jpg
#   inflating: /content/content/stage_3_dataset/107027.jpg
#   inflating: /content/content/stage_3_dataset/023532.jpg
#   inflating: /content/content/stage_3_dataset/063025.jpg
#   inflating: /content/content/stage_3_dataset/057476.jpg
#   inflating: /content/content/stage_3_dataset/123680.jpg
#   inflating: /content/content/stage_3_dataset/029356.jpg
#   inflating: /content/content/stage_3_dataset/139444.jpg
#   inflating: /content/content/stage_3_dataset/065795.jpg
#   inflating: /content/content/stage_3_dataset/044140.jpg
#   inflating: /content/content/stage_3_dataset/144275.jpg
#   inflating: /content/content/stage_3_dataset/109858.jpg
#   inflating: /content/content/stage_3_dataset/102102.jpg
#   inflating: /content/content/stage_3_dataset/122435.jpg
#   inflating: /content/content/stage_3_dataset/038947.jpg
#   inflating: /content/content/stage_3_dataset/127678.jpg
#   inflating: /content/content/stage_3_dataset/049230.jpg
#   inflating: /content/content/stage_3_dataset/017297.jpg
#   inflating: /content/content/stage_3_dataset/148305.jpg
#   inflating: /content/content/stage_3_dataset/150144.jpg
#   inflating: /content/content/stage_3_dataset/087119.jpg
#   inflating: /content/content/stage_3_dataset/088486.jpg
#   inflating: /content/content/stage_3_dataset/004039.jpg
#   inflating: /content/content/stage_3_dataset/113371.jpg
#   inflating: /content/content/stage_3_dataset/148568.jpg
#   inflating: /content/content/stage_3_dataset/026895.jpg
#   inflating: /content/content/stage_3_dataset/084823.jpg
#   inflating: /content/content/stage_3_dataset/065902.jpg
#   inflating: /content/content/stage_3_dataset/145734.jpg
#   inflating: /content/content/stage_3_dataset/130809.jpg
#   inflating: /content/content/stage_3_dataset/116789.jpg
#   inflating: /content/content/stage_3_dataset/089722.jpg
#   inflating: /content/content/stage_3_dataset/059526.jpg
#   inflating: /content/content/stage_3_dataset/078768.jpg
#   inflating: /content/content/stage_3_dataset/118942.jpg
#   inflating: /content/content/stage_3_dataset/011239.jpg
#   inflating: /content/content/stage_3_dataset/018837.jpg
#   inflating: /content/content/stage_3_dataset/044399.jpg
#   inflating: /content/content/stage_3_dataset/133237.jpg
#   inflating: /content/content/stage_3_dataset/025900.jpg
#   inflating: /content/content/stage_3_dataset/122950.jpg
#   inflating: /content/content/stage_3_dataset/069492.jpg
#   inflating: /content/content/stage_3_dataset/036271.jpg
#   inflating: /content/content/stage_3_dataset/070504.jpg
#   inflating: /content/content/stage_3_dataset/077501.jpg
#   inflating: /content/content/stage_3_dataset/051040.jpg
#   inflating: /content/content/stage_3_dataset/075233.jpg
#   inflating: /content/content/stage_3_dataset/060599.jpg
#   inflating: /content/content/stage_3_dataset/136633.jpg
#   inflating: /content/content/stage_3_dataset/150242.jpg
#   inflating: /content/content/stage_3_dataset/014726.jpg
#   inflating: /content/content/stage_3_dataset/106410.jpg
#   inflating: /content/content/stage_3_dataset/115899.jpg
#   inflating: /content/content/stage_3_dataset/063080.jpg
#   inflating: /content/content/stage_3_dataset/030809.jpg
#   inflating: /content/content/stage_3_dataset/130734.jpg
#   inflating: /content/content/stage_3_dataset/114136.jpg
#   inflating: /content/content/stage_3_dataset/065954.jpg
#   inflating: /content/content/stage_3_dataset/041199.jpg
#   inflating: /content/content/stage_3_dataset/093598.jpg
#   inflating: /content/content/stage_3_dataset/040388.jpg
#   inflating: /content/content/stage_3_dataset/105338.jpg
#   inflating: /content/content/stage_3_dataset/015086.jpg
#   inflating: /content/content/stage_3_dataset/097559.jpg
#   inflating: /content/content/stage_3_dataset/035767.jpg
#   inflating: /content/content/stage_3_dataset/075368.jpg
#   inflating: /content/content/stage_3_dataset/069947.jpg
#   inflating: /content/content/stage_3_dataset/104825.jpg
#   inflating: /content/content/stage_3_dataset/017792.jpg
#   inflating: /content/content/stage_3_dataset/087756.jpg
#   inflating: /content/content/stage_3_dataset/151721.jpg
#   inflating: /content/content/stage_3_dataset/034181.jpg
#   inflating: /content/content/stage_3_dataset/085830.jpg
#   inflating: /content/content/stage_3_dataset/126458.jpg
#   inflating: /content/content/stage_3_dataset/035313.jpg
#   inflating: /content/content/stage_3_dataset/107251.jpg
#   inflating: /content/content/stage_3_dataset/018380.jpg
#   inflating: /content/content/stage_3_dataset/044672.jpg
#   inflating: /content/content/stage_3_dataset/069714.jpg
#   inflating: /content/content/stage_3_dataset/031839.jpg
#   inflating: /content/content/stage_3_dataset/111985.jpg
#   inflating: /content/content/stage_3_dataset/137064.jpg
#   inflating: /content/content/stage_3_dataset/069241.jpg
#   inflating: /content/content/stage_3_dataset/118767.jpg
#   inflating: /content/content/stage_3_dataset/149915.jpg
#   inflating: /content/content/stage_3_dataset/086364.jpg
#   inflating: /content/content/stage_3_dataset/018141.jpg
#   inflating: /content/content/stage_3_dataset/001072.jpg
#   inflating: /content/content/stage_3_dataset/124893.jpg
#   inflating: /content/content/stage_3_dataset/104424.jpg
#   inflating: /content/content/stage_3_dataset/130874.jpg
#   inflating: /content/content/stage_3_dataset/003405.jpg
#   inflating: /content/content/stage_3_dataset/041900.jpg
#   inflating: /content/content/stage_3_dataset/080444.jpg
#   inflating: /content/content/stage_3_dataset/020554.jpg
#   inflating: /content/content/stage_3_dataset/101862.jpg
#   inflating: /content/content/stage_3_dataset/024023.jpg
#   inflating: /content/content/stage_3_dataset/008816.jpg
#   inflating: /content/content/stage_3_dataset/001888.jpg
#   inflating: /content/content/stage_3_dataset/042300.jpg
#   inflating: /content/content/stage_3_dataset/035401.jpg
#   inflating: /content/content/stage_3_dataset/014950.jpg
#   inflating: /content/content/stage_3_dataset/106286.jpg
#   inflating: /content/content/stage_3_dataset/095986.jpg
#   inflating: /content/content/stage_3_dataset/121230.jpg
#   inflating: /content/content/stage_3_dataset/082271.jpg
#   inflating: /content/content/stage_3_dataset/013905.jpg
#   inflating: /content/content/stage_3_dataset/097977.jpg
#   inflating: /content/content/stage_3_dataset/089213.jpg
#   inflating: /content/content/stage_3_dataset/041958.jpg
#   inflating: /content/content/stage_3_dataset/008042.jpg
#   inflating: /content/content/stage_3_dataset/054039.jpg
#   inflating: /content/content/stage_3_dataset/021974.jpg
#   inflating: /content/content/stage_3_dataset/021164.jpg
#   inflating: /content/content/stage_3_dataset/004558.jpg
#   inflating: /content/content/stage_3_dataset/029345.jpg
#   inflating: /content/content/stage_3_dataset/100944.jpg
#   inflating: /content/content/stage_3_dataset/006308.jpg
#   inflating: /content/content/stage_3_dataset/137122.jpg
#   inflating: /content/content/stage_3_dataset/036913.jpg
#   inflating: /content/content/stage_3_dataset/114913.jpg
#   inflating: /content/content/stage_3_dataset/043319.jpg
#   inflating: /content/content/stage_3_dataset/072392.jpg
#   inflating: /content/content/stage_3_dataset/102431.jpg
#   inflating: /content/content/stage_3_dataset/059387.jpg
#   inflating: /content/content/stage_3_dataset/070538.jpg
#   inflating: /content/content/stage_3_dataset/016695.jpg
#   inflating: /content/content/stage_3_dataset/007679.jpg
#   inflating: /content/content/stage_3_dataset/143579.jpg
# ...
#   inflating: /content/content/stage_3_dataset/129355.jpg
#   inflating: /content/content/stage_3_dataset/049001.jpg
#   inflating: /content/content/stage_3_dataset/068607.jpg
#   inflating: /content/content/stage_3_dataset/063292.jpg
#   inflating: /content/content/stage_3_dataset/005921.jpg
#   inflating: /content/content/stage_3_dataset/078056.jpg
#   inflating: /content/content/stage_3_dataset/036688.jpg
#   inflating: /content/content/stage_3_dataset/050860.jpg
#   inflating: /content/content/stage_3_dataset/042260.jpg
#   inflating: /content/content/stage_3_dataset/143158.jpg
#   inflating: /content/content/stage_3_dataset/054492.jpg
#   inflating: /content/content/stage_3_dataset/138022.jpg
#   inflating: /content/content/stage_3_dataset/002126.jpg
#   inflating: /content/content/stage_3_dataset/108996.jpg
#   inflating: /content/content/stage_3_dataset/033417.jpg
#   inflating: /content/content/stage_3_dataset/145863.jpg
#   inflating: /content/content/stage_3_dataset/066153.jpg
#   inflating: /content/content/stage_3_dataset/114310.jpg
#   inflating: /content/content/stage_3_dataset/136972.jpg
#   inflating: /content/content/stage_3_dataset/003921.jpg
#   inflating: /content/content/stage_3_dataset/015894.jpg
#   inflating: /content/content/stage_3_dataset/115924.jpg
#   inflating: /content/content/stage_3_dataset/127500.jpg
#   inflating: /content/content/stage_3_dataset/065961.jpg
#   inflating: /content/content/stage_3_dataset/015342.jpg
#   inflating: /content/content/stage_3_dataset/057035.jpg
#   inflating: /content/content/stage_3_dataset/092564.jpg
#   inflating: /content/content/stage_3_dataset/105266.jpg
#   inflating: /content/content/stage_3_dataset/060089.jpg
#   inflating: /content/content/stage_3_dataset/054255.jpg
#   inflating: /content/content/stage_3_dataset/014212.jpg
#   inflating: /content/content/stage_3_dataset/096580.jpg
#   inflating: /content/content/stage_3_dataset/033431.jpg
#   inflating: /content/content/stage_3_dataset/022160.jpg
#   inflating: /content/content/stage_3_dataset/103104.jpg
#   inflating: /content/content/stage_3_dataset/090486.jpg
#   inflating: /content/content/stage_3_dataset/123209.jpg
#   inflating: /content/content/stage_3_dataset/030630.jpg
#   inflating: /content/content/stage_3_dataset/002811.jpg
#   inflating: /content/content/stage_3_dataset/150717.jpg
#   inflating: /content/content/stage_3_dataset/001804.jpg
#   inflating: /content/content/stage_3_dataset/135898.jpg
#   inflating: /content/content/stage_3_dataset/104797.jpg
#   inflating: /content/content/stage_3_dataset/101688.jpg
#   inflating: /content/content/stage_3_dataset/068295.jpg
#   inflating: /content/content/stage_3_dataset/124185.jpg
#   inflating: /content/content/stage_3_dataset/025146.jpg
#   inflating: /content/content/stage_3_dataset/015082.jpg
#   inflating: /content/content/stage_3_dataset/090609.jpg
#   inflating: /content/content/stage_3_dataset/113921.jpg
#   inflating: /content/content/stage_3_dataset/120357.jpg
#   inflating: /content/content/stage_3_dataset/124977.jpg
#   inflating: /content/content/stage_3_dataset/040943.jpg
#   inflating: /content/content/stage_3_dataset/041105.jpg
#   inflating: /content/content/stage_3_dataset/072252.jpg
#   inflating: /content/content/stage_3_dataset/068374.jpg
#   inflating: /content/content/stage_3_dataset/139499.jpg
#   inflating: /content/content/stage_3_dataset/023286.jpg
#   inflating: /content/content/stage_3_dataset/015123.jpg
#   inflating: /content/content/stage_3_dataset/111858.jpg
#   inflating: /content/content/stage_3_dataset/104299.jpg
#   inflating: /content/content/stage_3_dataset/142783.jpg
#   inflating: /content/content/stage_3_dataset/026748.jpg
#   inflating: /content/content/stage_3_dataset/130560.jpg
#   inflating: /content/content/stage_3_dataset/121770.jpg
#   inflating: /content/content/stage_3_dataset/142374.jpg
#   inflating: /content/content/stage_3_dataset/118296.jpg
#   inflating: /content/content/stage_3_dataset/150442.jpg
#   inflating: /content/content/stage_3_dataset/001681.jpg
#   inflating: /content/content/stage_3_dataset/063032.jpg
#   inflating: /content/content/stage_3_dataset/053041.jpg
#   inflating: /content/content/stage_3_dataset/149661.jpg
#   inflating: /content/content/stage_3_dataset/064290.jpg
#   inflating: /content/content/stage_3_dataset/120883.jpg
#   inflating: /content/content/stage_3_dataset/054016.jpg
#   inflating: /content/content/stage_3_dataset/116863.jpg
#   inflating: /content/content/stage_3_dataset/081239.jpg
#   inflating: /content/content/stage_3_dataset/104467.jpg
#   inflating: /content/content/stage_3_dataset/077058.jpg
#   inflating: /content/content/stage_3_dataset/017856.jpg
#   inflating: /content/content/stage_3_dataset/000774.jpg
#   inflating: /content/content/stage_3_dataset/065916.jpg
#   inflating: /content/content/stage_3_dataset/087594.jpg
#   inflating: /content/content/stage_3_dataset/023763.jpg
#   inflating: /content/content/stage_3_dataset/004800.jpg
#   inflating: /content/content/stage_3_dataset/084610.jpg
#   inflating: /content/content/stage_3_dataset/076221.jpg
#   inflating: /content/content/stage_3_dataset/129242.jpg
#   inflating: /content/content/stage_3_dataset/030491.jpg
#   inflating: /content/content/stage_3_dataset/063567.jpg
#   inflating: /content/content/stage_3_dataset/051768.jpg
#   inflating: /content/content/stage_3_dataset/096910.jpg
#   inflating: /content/content/stage_3_dataset/132692.jpg
#   inflating: /content/content/stage_3_dataset/010972.jpg
#   inflating: /content/content/stage_3_dataset/065982.jpg
#   inflating: /content/content/stage_3_dataset/057906.jpg
#   inflating: /content/content/stage_3_dataset/116510.jpg
#   inflating: /content/content/stage_3_dataset/137947.jpg
#   inflating: /content/content/stage_3_dataset/104327.jpg
#   inflating: /content/content/stage_3_dataset/078041.jpg
#   inflating: /content/content/stage_3_dataset/060389.jpg
#   inflating: /content/content/stage_3_dataset/022007.jpg
#   inflating: /content/content/stage_3_dataset/150855.jpg
#   inflating: /content/content/stage_3_dataset/126266.jpg
#   inflating: /content/content/stage_3_dataset/063138.jpg
#   inflating: /content/content/stage_3_dataset/113603.jpg
#   inflating: /content/content/stage_3_dataset/001972.jpg
#   inflating: /content/content/stage_3_dataset/003013.jpg
#   inflating: /content/content/stage_3_dataset/060996.jpg
#   inflating: /content/content/stage_3_dataset/146750.jpg
#   inflating: /content/content/stage_3_dataset/089898.jpg
#   inflating: /content/content/stage_3_dataset/020252.jpg
#   inflating: /content/content/stage_3_dataset/031003.jpg
#   inflating: /content/content/stage_3_dataset/042710.jpg
#   inflating: /content/content/stage_3_dataset/017572.jpg
#   inflating: /content/content/stage_3_dataset/124135.jpg
#   inflating: /content/content/stage_3_dataset/082622.jpg
#   inflating: /content/content/stage_3_dataset/005296.jpg
#   inflating: /content/content/stage_3_dataset/129205.jpg
#   inflating: /content/content/stage_3_dataset/089486.jpg
#   inflating: /content/content/stage_3_dataset/151444.jpg
#   inflating: /content/content/stage_3_dataset/100475.jpg
#   inflating: /content/content/stage_3_dataset/050078.jpg
#   inflating: /content/content/stage_3_dataset/128630.jpg
#   inflating: /content/content/stage_3_dataset/004348.jpg
#   inflating: /content/content/stage_3_dataset/059492.jpg
#   inflating: /content/content/stage_3_dataset/104008.jpg
#   inflating: /content/content/stage_3_dataset/100293.jpg
#   inflating: /content/content/stage_3_dataset/105896.jpg
#   inflating: /content/content/stage_3_dataset/000691.jpg
#   inflating: /content/content/stage_3_dataset/006747.jpg
#   inflating: /content/content/stage_3_dataset/133273.jpg
#   inflating: /content/content/stage_3_dataset/141138.jpg
#   inflating: /content/content/stage_3_dataset/065996.jpg
#   inflating: /content/content/stage_3_dataset/048487.jpg
#   inflating: /content/content/stage_3_dataset/122447.jpg
#   inflating: /content/content/stage_3_dataset/082848.jpg
#   inflating: /content/content/stage_3_dataset/108396.jpg
#   inflating: /content/content/stage_3_dataset/129569.jpg
#   inflating: /content/content/stage_3_dataset/111304.jpg
#   inflating: /content/content/stage_3_dataset/026662.jpg
#   inflating: /content/content/stage_3_dataset/116019.jpg
#   inflating: /content/content/stage_3_dataset/143651.jpg
#   inflating: /content/content/stage_3_dataset/014269.jpg
#   inflating: /content/content/stage_3_dataset/033360.jpg
#   inflating: /content/content/stage_3_dataset/047890.jpg
#   inflating: /content/content/stage_3_dataset/065958.jpg
#   inflating: /content/content/stage_3_dataset/127376.jpg
#   inflating: /content/content/stage_3_dataset/123141.jpg
#   inflating: /content/content/stage_3_dataset/051912.jpg
#   inflating: /content/content/stage_3_dataset/005804.jpg
#   inflating: /content/content/stage_3_dataset/024245.jpg
#   inflating: /content/content/stage_3_dataset/007939.jpg
#   inflating: /content/content/stage_3_dataset/041517.jpg
#   inflating: /content/content/stage_3_dataset/032699.jpg
#   inflating: /content/content/stage_3_dataset/033762.jpg
#   inflating: /content/content/stage_3_dataset/014971.jpg
#   inflating: /content/content/stage_3_dataset/118419.jpg
#   inflating: /content/content/stage_3_dataset/119137.jpg
#   inflating: /content/content/stage_3_dataset/102526.jpg
#   inflating: /content/content/stage_3_dataset/094494.jpg
#   inflating: /content/content/stage_3_dataset/053892.jpg
#   inflating: /content/content/stage_3_dataset/124720.jpg
#   inflating: /content/content/stage_3_dataset/129719.jpg
#   inflating: /content/content/stage_3_dataset/018044.jpg
#   inflating: /content/content/stage_3_dataset/095888.jpg
#   inflating: /content/content/stage_3_dataset/002755.jpg
#   inflating: /content/content/stage_3_dataset/107352.jpg
#   inflating: /content/content/stage_3_dataset/112219.jpg
#   inflating: /content/content/stage_3_dataset/052729.jpg
#   inflating: /content/content/stage_3_dataset/003655.jpg
#   inflating: /content/content/stage_3_dataset/042445.jpg
#   inflating: /content/content/stage_3_dataset/037771.jpg
#   inflating: /content/content/stage_3_dataset/084234.jpg
#   inflating: /content/content/stage_3_dataset/059331.jpg
#   inflating: /content/content/stage_3_dataset/088367.jpg
#   inflating: /content/content/stage_3_dataset/063713.jpg
#   inflating: /content/content/stage_3_dataset/024144.jpg
#   inflating: /content/content/stage_3_dataset/142861.jpg
#   inflating: /content/content/stage_3_dataset/090036.jpg
#   inflating: /content/content/stage_3_dataset/085007.jpg
#   inflating: /content/content/stage_3_dataset/000150.jpg
#   inflating: /content/content/stage_3_dataset/112747.jpg
#   inflating: /content/content/stage_3_dataset/122664.jpg
#   inflating: /content/content/stage_3_dataset/047933.jpg
#   inflating: /content/content/stage_3_dataset/092150.jpg
#   inflating: /content/content/stage_3_dataset/124829.jpg
#   inflating: /content/content/stage_3_dataset/102728.jpg
#   inflating: /content/content/stage_3_dataset/138253.jpg
#   inflating: /content/content/stage_3_dataset/088607.jpg
#   inflating: /content/content/stage_3_dataset/107322.jpg
#   inflating: /content/content/stage_3_dataset/065393.jpg
#   inflating: /content/content/stage_3_dataset/007602.jpg
#   inflating: /content/content/stage_3_dataset/131368.jpg
#   inflating: /content/content/stage_3_dataset/074081.jpg
#   inflating: /content/content/stage_3_dataset/142480.jpg
#   inflating: /content/content/stage_3_dataset/087562.jpg
#   inflating: /content/content/stage_3_dataset/058424.jpg
#   inflating: /content/content/stage_3_dataset/010317.jpg
#   inflating: /content/content/stage_3_dataset/130699.jpg
#   inflating: /content/content/stage_3_dataset/055946.jpg
#   inflating: /content/content/stage_3_dataset/015753.jpg
#   inflating: /content/content/stage_3_dataset/052227.jpg
#   inflating: /content/content/stage_3_dataset/027577.jpg
#   inflating: /content/content/stage_3_dataset/004189.jpg
#   inflating: /content/content/stage_3_dataset/123605.jpg
#   inflating: /content/content/stage_3_dataset/096488.jpg
#   inflating: /content/content/stage_3_dataset/126895.jpg
#   inflating: /content/content/stage_3_dataset/100725.jpg
#   inflating: /content/content/stage_3_dataset/015743.jpg
#   inflating: /content/content/stage_3_dataset/100806.jpg
#   inflating: /content/content/stage_3_dataset/111172.jpg
#   inflating: /content/content/stage_3_dataset/017210.jpg
#   inflating: /content/content/stage_3_dataset/098042.jpg
#   inflating: /content/content/stage_3_dataset/003660.jpg
#   inflating: /content/content/stage_3_dataset/114646.jpg
#   inflating: /content/content/stage_3_dataset/130839.jpg
#   inflating: /content/content/stage_3_dataset/062112.jpg
#   inflating: /content/content/stage_3_dataset/032832.jpg
#   inflating: /content/content/stage_3_dataset/102472.jpg
#   inflating: /content/content/stage_3_dataset/144103.jpg
#   inflating: /content/content/stage_3_dataset/123668.jpg
#   inflating: /content/content/stage_3_dataset/048078.jpg
#   inflating: /content/content/stage_3_dataset/006656.jpg
#   inflating: /content/content/stage_3_dataset/029617.jpg
#   inflating: /content/content/stage_3_dataset/097385.jpg
#   inflating: /content/content/stage_3_dataset/105868.jpg
#   inflating: /content/content/stage_3_dataset/020407.jpg
#   inflating: /content/content/stage_3_dataset/013958.jpg
#   inflating: /content/content/stage_3_dataset/096866.jpg
#   inflating: /content/content/stage_3_dataset/070975.jpg
#   inflating: /content/content/stage_3_dataset/059284.jpg
#   inflating: /content/content/stage_3_dataset/055899.jpg
#   inflating: /content/content/stage_3_dataset/084082.jpg
#   inflating: /content/content/stage_3_dataset/006297.jpg
#   inflating: /content/content/stage_3_dataset/013154.jpg
#   inflating: /content/content/stage_3_dataset/110095.jpg
#   inflating: /content/content/stage_3_dataset/140967.jpg
#   inflating: /content/content/stage_3_dataset/093176.jpg
#   inflating: /content/content/stage_3_dataset/050706.jpg
#   inflating: /content/content/stage_3_dataset/016496.jpg
#   inflating: /content/content/stage_3_dataset/122046.jpg
#   inflating: /content/content/stage_3_dataset/116394.jpg
#   inflating: /content/content/stage_3_dataset/029329.jpg
#   inflating: /content/content/stage_3_dataset/014135.jpg
#   inflating: /content/content/stage_3_dataset/103164.jpg
#   inflating: /content/content/stage_3_dataset/129478.jpg
#   inflating: /content/content/stage_3_dataset/107916.jpg
#   inflating: /content/content/stage_3_dataset/082515.jpg
#   inflating: /content/content/stage_3_dataset/013386.jpg
#   inflating: /content/content/stage_3_dataset/150249.jpg
#   inflating: /content/content/stage_3_dataset/111290.jpg
#   inflating: /content/content/stage_3_dataset/038099.jpg
#   inflating: /content/content/stage_3_dataset/004350.jpg
#   inflating: /content/content/stage_3_dataset/093164.jpg
#   inflating: /content/content/stage_3_dataset/056116.jpg
#   inflating: /content/content/stage_3_dataset/002002.jpg
#   inflating: /content/content/stage_3_dataset/008290.jpg
#   inflating: /content/content/stage_3_dataset/029015.jpg
#   inflating: /content/content/stage_3_dataset/055134.jpg
#   inflating: /content/content/stage_3_dataset/108340.jpg
#   inflating: /content/content/stage_3_dataset/145446.jpg
#   inflating: /content/content/stage_3_dataset/092159.jpg
#   inflating: /content/content/stage_3_dataset/046189.jpg
#   inflating: /content/content/stage_3_dataset/047016.jpg
#   inflating: /content/content/stage_3_dataset/038151.jpg
#   inflating: /content/content/stage_3_dataset/099236.jpg
#   inflating: /content/content/stage_3_dataset/063660.jpg
#   inflating: /content/content/stage_3_dataset/144251.jpg
#   inflating: /content/content/stage_3_dataset/094759.jpg
#   inflating: /content/content/stage_3_dataset/006037.jpg

# %% [markdown]
# Файл с парами "имя картинки" - id и создаем DataFrame

# %%
# !gdown 1pmjLR8zU17IQTVWYZrzLU_-XR33f1RtJ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1pmjLR8zU17IQTVWYZrzLU_-XR33f1RtJ
# To: /content/identity_CelebA.txt
# 100% 3.42M/3.42M [00:00<00:00, 26.7MB/s]

# %%
df = pd.read_csv('/content/identity_CelebA.txt', delim_whitespace=True, header=None,index_col=0)
# Out:
# /tmp/ipython-input-10-1097142516.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('/content/identity_CelebA.txt', delim_whitespace=True, header=None,index_col=0)

# %%
df.index.name = 'image_name'
df.rename(columns={1:'id'},inplace=True)

# %% [markdown]
# Находим файлы, которые не были использованы во время обучения модели

# %%
def get_filenames_os(folder_path):
    files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    return files

# %%
all_filenames = get_filenames_os('/content/celeba/img_align_celeba')

# %%
used_filenames = get_filenames_os('/content/content/stage_3_dataset')

# %%
unused_filenames = list(set(all_filenames) ^ set(used_filenames))

# %%
used_files_dataframe = df.loc[used_filenames]
used_ids = used_files_dataframe['id']
unused_files_dataframe = df.loc[unused_filenames]

unused_filed_unique_id_df = unused_files_dataframe[~unused_files_dataframe["id"].isin(used_ids)]

# %%
query_ids = unused_filed_unique_id_df.value_counts().sample(30).index.to_list()
query_ids = list(chain(*query_ids))

# %%
distractors_img_names = unused_filed_unique_id_df[~unused_filed_unique_id_df['id'].isin(query_ids)].sample(500).index.to_list()

# %%
query_dict = {}
query_img_names = []
for id in query_ids:
    img_names = unused_filed_unique_id_df[unused_filed_unique_id_df['id']==id].head(5).index.to_list()
    query_dict[id] = img_names
    query_img_names += img_names

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Шаблон кода для Identificaton rate metric (TPR@FPR)

# %%
img_dir = '/content/celeba/img_align_celeba'

# %%
transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
])

# %%
@torch.no_grad()
def compute_embeddings(model, images_list):
    '''
    compute embeddings from the trained model for list of images.
    params:
      model: trained nn model that takes images and outputs embeddings
      images_list: list of images paths to compute embeddings for
    output:
      list: list of model embeddings. Each embedding corresponds to images
            names from images_list
    '''
    model.eval()

    embeddings = []

    for img_name in tqdm(images_list):

        img_path = os.path.join(img_dir, img_name)
        image = Image.open(img_path).convert('RGB')

        image_tensor = transform(image)
        image_tensor = image_tensor.unsqueeze(0)
        image_tensor = image_tensor.to(device)

        embedding = model(image_tensor)
        embeddings.append(embedding.cpu().detach().numpy())


    return embeddings

# %%
backbone = models.resnet18(pretrained=True)
backbone.fc = nn.Identity()
model = nn.Sequential(backbone, nn.Flatten()).to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# !gdown 1dN4ozx8EEBiCe3j1tP9bjZHH7HaO4RX9
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1dN4ozx8EEBiCe3j1tP9bjZHH7HaO4RX9
# From (redirected): https://drive.google.com/uc?id=1dN4ozx8EEBiCe3j1tP9bjZHH7HaO4RX9&confirm=t&uuid=859a48e7-9a1b-4144-a412-00074b83bfd2
# To: /content/best_recognition_model_arc.pth
# 100% 61.6M/61.6M [00:00<00:00, 71.0MB/s]

# %%
saved_model = torch.load('/content/best_recognition_model_arc.pth', map_location=device)

# %%
model.load_state_dict(saved_model['model'])
model = model.to(device)

# %%
query_embeddings = compute_embeddings(model, query_img_names)
distractors_embeddings = compute_embeddings(model, distractors_img_names)
# Out:
#   0%|          | 0/145 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
F.cosine_similarity(torch.tensor(query_embeddings[0]), torch.tensor(distractors_embeddings[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-120-310213584.py in <cell line: 0>()
# ----> 1 F.cosine_similarity(query_embeddings[0], distractors_embeddings[0])
#
# TypeError: cosine_similarity(): argument 'x1' (position 1) must be Tensor, not numpy.ndarray

# %%
# Out:
# (1, 512)

# %%
def compute_cosine_query_pos(query_dict: dict, query_img_names, query_embeddings):
    '''
    compute cosine similarities between positive pairs from query (stage 1)
    params:
      query_dict: dict {class: [image_name_1, image_name_2, ...]}. Key: class in
                  the dataset. Value: images corresponding to that class
      query_img_names: list of images names
      query_embeddings: list of embeddings corresponding to query_img_names
    output:
      list of floats: similarities between embeddings corresponding
                      to the same people from query list
    '''

    embeddings_map = { img_name:embedding for img_name, embedding in zip(query_img_names, query_embeddings) }
    similarities = []

    for image_names in query_dict.values():
        embeddings = [ embeddings_map[img_name] for img_name in image_names ]
        emd_pairs = combinations(embeddings, 2)

        for emb1, emb2 in emd_pairs:
            emb1, emb2 = torch.tensor(emb1), torch.tensor(emb2)
            cos_sim = F.cosine_similarity(emb1.unsqueeze(0), emb2.unsqueeze(0)).item()
            similarities.append(cos_sim)

    return similarities

def compute_cosine_query_neg(query_dict, query_img_names, query_embeddings):
    '''
    compute cosine similarities between negative pairs from query (stage 2)
    params:
      query_dict: dict {class: [image_name_1, image_name_2, ...]}. Key: class in
                  the dataset. Value: images corresponding to that class
      query_img_names: list of images names
      query_embeddings: list of embeddings corresponding to query_img_names
    output:
      list of floats: similarities between embeddings corresponding
                      to different people from query list
    '''
    embeddings_map = { img_name:embedding for img_name, embedding in zip(query_img_names, query_embeddings) }
    similarities = []
    img_id_list = []

    for id, img_names in query_dict.items():
        for img_name in img_names:
            img_id_list.append((img_name,id))

    image_comb = combinations(img_id_list,2)

    for pair1, pair2 in image_comb:
        id1, id2 = pair1[1], pair2[1]
        if id1==id2:
            continue
        img_name1, img_name2 = pair1[0], pair2[0]
        emb1, emb2 = embeddings_map[img_name1], embeddings_map[img_name2]
        emb1, emb2 = torch.tensor(emb1), torch.tensor(emb2)
        cos_sim = F.cosine_similarity(emb1.unsqueeze(0), emb2.unsqueeze(0)).item()
        similarities.append(cos_sim)

    return similarities

def compute_cosine_query_distractors(query_embeddings, distractors_embeddings):
    '''
    compute cosine similarities between negative pairs from query and distractors
    (stage 3)
    params:
      query_embeddings: list of embeddings corresponding to query_img_names
      distractors_embeddings: list of embeddings corresponding to distractors_img_names
    output:
      list of floats: similarities between pairs of people (q, d), where q is
                      embedding corresponding to photo from query, d —
                      embedding corresponding to photo from distractors
    '''
    similarities = []

    for q_emb in query_embeddings:
        q_emb = torch.tensor(q_emb).unsqueeze(0)
        for d_emb in distractors_embeddings:
            d_emb = torch.tensor(d_emb).unsqueeze(0)
            cos_sim = F.cosine_similarity(q_emb, d_emb).item()
            similarities.append(cos_sim)

    return similarities

# %%
cosine_query_pos = compute_cosine_query_pos(query_dict, query_img_names,
                                            query_embeddings)
cosine_query_neg = compute_cosine_query_neg(query_dict, query_img_names,
                                            query_embeddings)
cosine_query_distractors = compute_cosine_query_distractors(query_embeddings,
                                                            distractors_embeddings)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-114-2596120237.py in <cell line: 0>()
# ----> 1 cosine_query_pos = compute_cosine_query_pos(query_dict, query_img_names,
#       2                                             query_embeddings)
#       3 cosine_query_neg = compute_cosine_query_neg(query_dict, query_img_names,
#       4                                             query_embeddings)
#       5 cosine_query_distractors = compute_cosine_query_distractors(query_embeddings,
#
# /tmp/ipython-input-113-1563630210.py in compute_cosine_query_pos(query_dict, query_img_names, query_embeddings)
#      21         for emb1, emb2 in emd_pairs:
#      22             emb1, emb2 = torch.tensor(emb1), torch.tensor(emb2)
# ---> 23             cos_sim = F.cosine_similarity(emb1.unsqueeze(0), emb2.unsqueeze(0)).item()
#      24             similarities.append(cos_sim)
#      25
#
# RuntimeError: a Tensor with 512 elements cannot be converted to Scalar

# %% [markdown]
# Ячейка ниже проверяет, что код работает верно:

# %%
test_query_dict = {
    2876: ['1.jpg', '2.jpg', '3.jpg'],
    5674: ['5.jpg'],
    864:  ['9.jpg', '10.jpg'],
}
test_query_img_names = ['1.jpg', '2.jpg', '3.jpg', '5.jpg', '9.jpg', '10.jpg']
test_query_embeddings = [
                    [1.56, 6.45,  -7.68],
                    [-1.1 , 6.11,  -3.0],
                    [-0.06,-0.98,-1.29],
                    [8.56, 1.45,  1.11],
                    [0.7,  1.1,   -7.56],
                    [0.05, 0.9,   -2.56],
]

test_distractors_img_names = ['11.jpg', '12.jpg', '13.jpg', '14.jpg', '15.jpg']

test_distractors_embeddings = [
                    [0.12, -3.23, -5.55],
                    [-1,   -0.01, 1.22],
                    [0.06, -0.23, 1.34],
                    [-6.6, 1.45,  -1.45],
                    [0.89,  1.98, 1.45],
]

test_cosine_query_pos = compute_cosine_query_pos(test_query_dict, test_query_img_names,
                                            test_query_embeddings)
test_cosine_query_neg = compute_cosine_query_neg(test_query_dict, test_query_img_names,
                                            test_query_embeddings)
test_cosine_query_distractors = compute_cosine_query_distractors(test_query_embeddings,
                                                            test_distractors_embeddings)

# %%
true_cosine_query_pos = [0.8678237233650096, 0.21226104378511604,
                         -0.18355866977496182, 0.9787437979250561]
assert np.allclose(sorted(test_cosine_query_pos), sorted(true_cosine_query_pos)), \
      "A mistake in compute_cosine_query_pos function"

true_cosine_query_neg = [0.15963231223161822, 0.8507997093616965, 0.9272761484302097,
                         -0.0643994061127092, 0.5412660901220571, 0.701307100338029,
                         -0.2372575528216902, 0.6941032794522218, 0.549425446066643,
                         -0.011982733001947084, -0.0466679194884999]
assert np.allclose(sorted(test_cosine_query_neg), sorted(true_cosine_query_neg)), \
      "A mistake in compute_cosine_query_neg function"

true_cosine_query_distractors = [0.3371426578637511, -0.6866465610863652, -0.8456563512871669,
                                 0.14530087113136106, 0.11410510307646118, -0.07265097629002357,
                                 -0.24097699660707042,-0.5851992679925766, 0.4295494455718534,
                                 0.37604478596058194, 0.9909483738948858, -0.5881093317868022,
                                 -0.6829712976642919, 0.07546364489032083, -0.9130970963915521,
                                 -0.17463101988684684, -0.5229363015558941, 0.1399896725311533,
                                 -0.9258034013399499, 0.5295114163723346, 0.7811585442749943,
                                 -0.8208760031249596, -0.9905139680301821, 0.14969764653247228,
                                 -0.40749654525418444, 0.648660814944824, -0.7432584300096284,
                                 -0.9839696492435877, 0.2498741082804709, -0.2661183373780491]
assert np.allclose(sorted(test_cosine_query_distractors), sorted(true_cosine_query_distractors)), \
      "A mistake in compute_cosine_query_distractors function"

# %% [markdown]
# И, наконец, финальная функция, которая считает IR metric:

# %%
def compute_ir(cosine_query_pos, cosine_query_neg, cosine_query_distractors,
               fpr=0.1):
    '''
    compute identification rate using precomputer cosine similarities between pairs
    at given fpr
    params:
      cosine_query_pos: cosine similarities between positive pairs from query
      cosine_query_neg: cosine similarities between negative pairs from query
      cosine_query_distractors: cosine similarities between negative pairs
                                from query and distractors
      fpr: false positive rate at which to compute TPR
    output:
      float: threshold for given fpr
      float: TPR at given FPR
    '''

    false_pairs = cosine_query_neg + cosine_query_distractors
    num_false_pairs = len(false_pairs)
    sorted_false_pairs = sorted(false_pairs, reverse=True)
    N = int(fpr * num_false_pairs)

    threshold = sorted_false_pairs[N] if N < len(sorted_false_pairs) else 0
    tp = len(list(filter(lambda sim:sim>threshold,cosine_query_pos)))
    tpr = tp / len(cosine_query_pos)


    return threshold, tpr

# %% [markdown]
# И ячейки для ее проверки:

# %%
test_thr = []
test_tpr = []
for fpr in [0.5, 0.3, 0.1]:
  x, y = compute_ir(test_cosine_query_pos, test_cosine_query_neg,
                    test_cosine_query_distractors, fpr=fpr)
  test_thr.append(x)
  test_tpr.append(y)

# %%
true_thr = [-0.011982733001947084, 0.3371426578637511, 0.701307100338029]
assert np.allclose(np.array(test_thr), np.array(true_thr)), "A mistake in computing threshold"

true_tpr = [0.75, 0.5, 0.5]
assert np.allclose(np.array(test_tpr), np.array(true_tpr)), "A mistake in computing tpr"

# %% [markdown]
# А в ячейке ниже вы можете посчитать TPR@FPR для датасета с лицами. Давайте, например, посчитаем для значений fpr = [0.5, 0.2, 0.1, 0.05].

# %%
# YOUR CODE HERE
