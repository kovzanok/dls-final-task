# %% [markdown]
# <a href="https://colab.research.google.com/github/kovzanok/dls-final-task/blob/main/2_ArcFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ArcFace Loss (Additive Angular Margin Loss)

# %% [markdown]
# ## Теория ArcFace

# %% [markdown]
# В случае с обучением на задачу классификации первая подходящая лосс-функция, которая нам приходит в голову — Cross-Entropy. И на ней действительно можно обучать сеть для распознавания лиц. Но за много лет люди придумали более хитрые лосс-функции, которые делают обучение сети для распознавания лиц более эффективным. Одним из лучших считается ArcFace Loss (Additive Angular Margin Loss).
#
# Этот лосс — чуть измененная кросс-энтропия. Он позволяет достичь лучшего распределения векторов лиц на сфере. В нем добавлены некоторые дополнительные ограничения и гиперпараметры, для того чтобы эмбеддинги лиц одного класса были более близки между собой, а эмбеддинги лиц разных людей оставались далеки. То есть, этот лосс позволяет лучше кластеризовать лица на сфере единичного радиуса.

# %% [markdown]
# **Как устроен ArcFace**:
#
# Стандартные SoftMax + кросс-энтропия (CE) выглядят так:
#
# $$L_{CE} = \frac{-1}{N}\sum_1^N \frac{e^{W_{y_i}^{T}x_i + b_{y_i}}}{\sum^n_{j=1}e^{W_j^Tx_i+b_j}},$$
#
# здесь:
# - $x_i \in \mathbb{R^d}$ — вектор $i$-го элемента обучающей выборки перед последним полносвязным слоем сети. $y_i$ — класс этого элемента;
# - $W_j \in \mathbb{R^d}$ — j-ый столбец матрицы весов последнего слоя сети (т.е. слоя, который производит итоговую классификацю входящего объекта);
# - $b_j \in \mathbb{R^d}$ — j-ый элемент вектора байеса последнего слоя сети;
# - $N$ — batch size;
# - $n$ — количество классов.
#
#
# Хотя этот лосс работает хорошо, он явным образом не заставляет эмбеддинги $x_i$ элементов, принадлежащих одному классу, быть близкими друг к другу по расстоянию. И не заставляет эмбеддинги элементов, принадлежащих разным классам, быть далеко друг от друга. Все, что хочет этот лосс — чтобы на основе эмбеддингов $x_i$ можно было хорошо классифицировать элементы, никакие ограничений на расстояния между эмбеддингами $x_i$ он не вводит.
#
# Из-за этого у нейросетей для распознавания лиц, которые обучены на обычном CE loss, бывают проблемы с распознаванием лиц, которые сильно отличаются от лиц того же человека разными допатрибутами (шляпа/прическа/очки и т.п.). Просто эмбеддинг для таких лиц получается довольно далек по расстоянию от других эмбеддингов лиц этого же человека.
#
# Давайте теперь немного поправим формулу:
# - уберем байес последнего слоя, т.е. сделаем $b_j=0$;
# - нормализуем веса последнего слоя: ||$W_j$|| = 1;
# - нормализуем эмбеддинги: ||$x_i$|| = 1. Перед подачей их на вход последнему слою (т.е. перед умножением на матрицу $W_j$) умножим их на гиперпараметр s. По сути, мы приводим норму всех эмбеддингов к s. Смысл этого гиперпараметра в том, что, возможно, сети проще будет классифицировать эмбеддинги, у которых не единичная норма.
#
# Нормализация эмбеддингов приводит к тому, что эмбеддинги начинают быть распределены по сфере единичного радиуса (и сфере радиуса s после умножения на ниперпараметр s). И итоговые предсказания сети после последнего слоя зависят только от угла между эмбеддингами $x_i$ и выученных весов $W_j$. От нормы эмбеддинга $x_i$ они больше не зависят, т.к. у всех эмбеддингов они теперь одинаковые.
#
# Получается, в степени экспоненты у нас останется выражение $s W_{y_i}^{T}x_i$, которое можно переписать в виде  $s W_{y_i}^{T}x_i = s ||W_{y_i}||\cdot ||x_i|| \cdot cos\Theta_{y_i}$. Тут $\Theta_{y_i}$ — это угод между векторами $W_{y_i}$ и $x_i$. Но так как мы сделали нормы $W_{y_i}$ и $x_i$ единичными, то все это выражение просто будет равно $s cos\Theta_{y_i}$.
#
# В итоге мы получим следующую формулу лосса:
#
# $$L = \frac{-1}{N}\sum_1^N \frac{e^{s\ cos\Theta_{y_i}}}{e^{s\ cos\Theta_{y_i}} + \sum^n_{j=1,\ j\ne y_i} e^{s\ cos\Theta_j}}$$
#
#
# И последний шаг. Добавим еще один гиперпараметр $m$. Он называется additive angular margin penalty и заставляет эмбеддинги одного класса быть ближе друг к другу, а эмбеддинги разных классов — более далекими друг от друга.
#
# В итоге получим вот что:
#
# $$L_{ArcFace} = \frac{-1}{N}\sum_1^N \frac{e^{s\ cos(\Theta_{y_i} + m)}}{e^{s\ cos(\Theta_{y_i} + m)} + \sum^n_{j=1,\ j\ne y_i} e^{s\ cos\Theta_j}}$$
#
# Это и есть ArcFace Loss с двумя  гиперпараметрами, s и m.
#
# Получается, что ArcFace Loss завтавляет сеть выучивать эмбеддинги, распределенные по сфере радиуса s, причем чтобы эмбеддинги одного класса были ближе друг к другу, а эмбеддинги разных классов — более далеки друг от друга.

# %% [markdown]
# **Доплитература по ArcFace Loss:**
#
# Оригинальная статья: https://arxiv.org/pdf/1801.07698.pdf

# %% [markdown]
# ## Другие лоссы

# %% [markdown]
# Кроме ArcFace, есть еще много разных вариантов лоссов для задачи face recognition. Некоторые из них можно найти, например, [тут](https://openaccess.thecvf.com/content_CVPRW_2020/papers/w48/Hsu_A_Comprehensive_Study_on_Loss_Functions_for_Cross-Factor_Face_Recognition_CVPRW_2020_paper.pdf). Вы можете попробовать реализовать другие лосс-функции в этом проекте в качестве дополнительного задания.
#
# Кроме этого, можно миксовать лосс-функции. Например, обучать нейросеть на сумме ArcFace и TripletLoss. Часто так выходит лучше, чем если обучать на каком-то одном лоссе.

# %% [markdown]
# # Датасет

# %% [markdown]
# В качестве датасета нужно использовать картинки из CelebA, выровненные при помощи своей модели из задания 1. Очень желательно их еще кропнуть таким образом, чтобы нейросети поступали на вход преимущественно только лица без какого либо фона, частей тела и прочего. Целиком брать весь датасет CelebA не обязательно, он слишком большой.
#
# Если планируете делать дополнительное задание на Identificaton rate metric, то **обязательно разбейте заранее датасет на train/val или train/val/test.** Это нужно сделать не только на уровне кода, а на уровне папок, чтобы точно знать, на каких картинках модель обучалась, а на каких нет. Лучше заранее почитайте [ноутбук с заданием](https://colab.research.google.com/drive/1sjO2-N8EsLb2HQcOELikFQCqKUWrPehJ?usp=sharing).

# %% [markdown]
# # План заданий

# %% [markdown]
# Итак, вот, что от вас требуется в этом задании:
#
# * Выбрать модель (или несколько моделей) для обучения. Можно брать предобученные на ImageNet, но нельзя использовать модели, предобученные на задачу распознавания лиц.
# * Обучить эту модель (модели) на CE loss. Добиться accuracy > 0.7.
# * Реализовать ArcFace loss.
# * Обучить модель (модели) на ArcFace loss. Добиться accuracy > 0.7.
# * Написать небольшой отчет по обучению, сравнить CE loss и ArcFace loss.
#
# **P.S. Не забывайте сохранять модели после обучения**

# %% [markdown]
# #Зависимости и загрузка данных

# %%
# !gdown --id 1bHLaSZ2frNjyK2hLTXTuPFlFRxfJDxwb
# !gdown --id
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1bHLaSZ2frNjyK2hLTXTuPFlFRxfJDxwb
#
# but Gdown can't. Please check connections and permissions.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !gdown 1bHLaSZ2frNjyK2hLTXTuPFlFRxfJDxwb
# !gdown 1pmjLR8zU17IQTVWYZrzLU_-XR33f1RtJ
# !gdown 1SLMKar0E9fgOvhrzqp7kwpk27MnSA39s
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1bHLaSZ2frNjyK2hLTXTuPFlFRxfJDxwb
# From (redirected): https://drive.google.com/uc?id=1bHLaSZ2frNjyK2hLTXTuPFlFRxfJDxwb&confirm=t&uuid=5a37b8ba-ea0c-4cf4-b899-d8b9136cef6b
# To: /kaggle/working/file.zip
# 100%|████████████████████████████████████████| 401M/401M [00:04<00:00, 97.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1pmjLR8zU17IQTVWYZrzLU_-XR33f1RtJ
# To: /kaggle/working/identity_CelebA.txt
# 100%|██████████████████████████████████████| 3.42M/3.42M [00:00<00:00, 27.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1SLMKar0E9fgOvhrzqp7kwpk27MnSA39s
# From (redirected): https://drive.google.com/uc?id=1SLMKar0E9fgOvhrzqp7kwpk27MnSA39s&confirm=t&uuid=11eb58f7-24e8-45a2-9dcb-f11808d0fb1c
# To: /kaggle/working/best_recognition_model.pth
# 100%|██████████████████████████████████████| 61.6M/61.6M [00:01<00:00, 59.8MB/s]

# %%
# !unzip /kaggle/working/file.zip -d /kaggle/working
# Out:
# Archive:  /kaggle/working/file.zip
#    creating: /kaggle/working/content/stage_3_dataset/
#   inflating: /kaggle/working/content/stage_3_dataset/037680.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/063677.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/022732.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/052167.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/151291.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/001343.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/009545.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/064630.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/026792.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/140391.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/028674.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/006860.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/120888.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/022133.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/048052.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/018148.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/096475.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/081878.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/101141.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/112139.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/124617.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/035270.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/068798.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/104305.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/139546.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/068807.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/149638.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/075708.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/148584.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/012936.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/134252.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/065684.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/089115.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/101208.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/057820.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/113919.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/078518.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/067754.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/124932.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/138878.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/011188.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/090289.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/121403.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/059245.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/070626.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/051222.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/142966.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/011469.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/077681.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/000440.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/050536.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/000641.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/147782.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/126255.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/036896.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/017034.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/114205.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/107623.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/115608.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/000378.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/066121.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/131788.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/041113.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/133950.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/084562.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/113329.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/124221.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/093693.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/060353.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/075740.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/090886.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/067451.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/141997.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/070228.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/026950.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/017784.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/075070.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/073990.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/066377.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/068848.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/127074.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/048399.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/075557.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/043391.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/146283.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/029906.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/047452.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/106651.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/123260.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/095775.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/003888.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/039952.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/031512.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/122607.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/147076.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/100844.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/054903.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/147158.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/041801.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/073618.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/018451.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/032608.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/063085.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/040156.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/006107.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/033671.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/027275.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/129398.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/090823.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/038608.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/079139.jpg
#   inflating: /kaggle/working/content/stage_3_dataset
jpg
#   inflating: /kaggle/working/content/stage_3_dataset/145280.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/095347.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/087532.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/077747.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/083253.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/015460.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/001010.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/027592.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/149601.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/143231.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/012674.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/103620.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/064832.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/122645.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/026917.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/103471.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/132822.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/145343.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/145806.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/075533.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/087316.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/053538.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/102127.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/028856.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/100884.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/046084.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/124390.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/003399.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/003456.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/079006.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/076685.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/092668.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/006827.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/097114.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/099565.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/088296.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/142663.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/055010.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/149681.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/144346.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/026807.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/098439.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/143605.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/132301.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/107842.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/002731.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/116275.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/066954.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/047332.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/053228.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/095194.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/093630.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/069393.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/150434.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/030014.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/014949.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/145704.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/016876.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/058626.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/147761.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/108283.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/103479.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/137736.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/013644.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/113937.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/085689.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/078171.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/013320.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/066486.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/130897.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/068681.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/083923.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/026542.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/009771.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/112090.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/077639.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/126079.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/073922.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/151836.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/026965.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/044785.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/023019.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/121463.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/019969.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/047012.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/140955.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/101576.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/045201.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/031247.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/097888.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/013864.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/069792.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/135112.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/012880.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/141066.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/148662.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/061537.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/106818.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/016899.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/069363.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/031055.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/102517.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/039746.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/111370.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/106108.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/050074.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/140023.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/055634.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/064930.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/036266.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/001308.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/087230.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/135561.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/083010.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/099424.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/031857.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/101602.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/021360.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/130262.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/138920.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/129165.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/113540.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/078363.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/145390.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/096176.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/060059.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/083725.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/129827.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/140497.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/115694.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/130933.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/094125.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/128534.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/081163.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/041419.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/101470.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/059824.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/049679.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/130499.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/013395.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/102379.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/140947.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/003305.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/063791.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/028127.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/085424.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/024853.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/031114.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/087635.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/022404.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/051399.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/118066.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/108169.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/127827.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/099583.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/016458.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/026083.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/030329.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/059716.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/004545.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/072688.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/112622.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/128819.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/100487.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/088041.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/113669.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/005420.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/031934.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/096198.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/032757.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/027176.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/145505.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/130052.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/105060.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/000282.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/078488.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/123003.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/102725.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/132050.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/069852.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/050827.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/000481.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/073150.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/027641.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/061196.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/045659.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/034758.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/096412.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/128933.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/005284.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/037333.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/000944.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/000587.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/144680.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/103146.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/093659.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/037547.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/001864.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/102036.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/123547.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/140357.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/105456.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/107366.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/094930.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/059623.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/044336.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/065096.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/037867.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/139075.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/132676.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/084831.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/091819.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/012494.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/014273.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/056500.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/008999.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/023027.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/000088.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/126658.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/135467.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/131457.jpg
#   inflating: /kaggle/working/content/stage_3_dataset/054343.jpg

# %%
# !unzip /content/drive/MyDrive/file.zip -d /content/
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/file.zip, /content/drive/MyDrive/file.zip.zip or /content/drive/MyDrive/file.zip.ZIP.

# %%
from torch import nn
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader, random_split, Subset
from PIL import Image
import torchvision.transforms as transforms
import torchvision.utils as vutils
import torchvision.models as models
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import torchvision.transforms.functional as TF
import cv2
from sklearn.preprocessing import LabelEncoder


import random
import os

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %% [markdown]
# #Датасет

# %%
path = '/content/drive/MyDrive/identity_CelebA.txt'
path = '/kaggle/working/identity_CelebA.txt'

df = pd.read_csv(path, delim_whitespace=True, header=None,index_col=0)
# Out:
# <ipython-input-6-ff7080cbe966>:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('/content/drive/MyDrive/identity_CelebA.txt', delim_whitespace=True, header=None,index_col=0)

# %%
df.index.name = 'image_name'
df.rename(columns={1:'id'},inplace=True)

# %%
df.head()
# Out:
#               id
# image_name
# 000001.jpg  2880
# 000002.jpg  2937
# 000003.jpg  8692
# 000004.jpg  5805
# 000005.jpg  9295

# %%
def get_filenames_os(folder_path):
    files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    return files

# %%
path = '/content/content/stage_3_dataset'
path = '/kaggle/working/stage_3_dataset''
filenames = get_filenames_os(path)

# %%
filtered_df = df.loc[filenames]

# %%
le = LabelEncoder()
filtered_df['encoded_id'] = le.fit_transform(filtered_df['id'])

# %%
class CelebADataset(Dataset):
    def __init__(self, img_dir, img_names, image_df, transform=None):
        super().__init__()
        self.img_dir = img_dir
        self.transform = transform
        self.image_names = img_names
        self.image_df = image_df

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):
        img_name = self.image_names[idx]
        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        id = self.image_df.loc[img_name]['encoded_id']

        return image, int(id)

# %%
transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.RandomAffine(degrees=5, translate=(0.02, 0.02)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
])


path = '/content/content/stage_3_dataset'
path = '/kaggle/working/stage_3_dataset'
dataset = CelebADataset(
    img_dir=path,
    transform=transform,
    image_df=filtered_df,
    img_names = filtered_df.index.to_list()
)

# %%
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=128)

# %% [markdown]
# #Модель

# %%
num_classes = int(filtered_df.nunique().values[0])

model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, num_classes)

# %%
path = '/content/drive/MyDrive/best_recognition_model_0,33.pth'
path = '/kaggle/working/best_recognition_model.pth'
model.load_state_dict(torch.load())
# Out:
# <All keys matched successfully>

# %%
for name, param in model.named_parameters():
    if 'layer4' in name or 'fc' in name:
        param.requires_grad = True
    else:
        param.requires_grad = False

# %%
model = model.to(device)

# %% [markdown]
# #Обучение

# %%
criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

# %%
def train_epoch(model, criterion, optimizer, train_loader):
    model.train()
    running_loss = 0
    for image, label in tqdm(train_loader,leave=False):
        image, label = image.to(device), label.to(device)

        logit = model(image)
        loss = criterion(logit, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)

    return avg_loss

# %%
@torch.no_grad()
def val_epoch(model, criterion,val_loader):
    model.eval()

    running_loss = 0
    correct = 0
    total = 0

    for image, label in tqdm(val_loader, leave=False):
        image, label = image.to(device), label.to(device)
        logit = model(image)

        loss = criterion(logit, label)

        running_loss += loss.item()
        _, predicted = torch.max(logit, 1)

        correct += (predicted == label).sum().item()
        total += label.size(0)

    avg_loss = running_loss / len(val_loader)
    accuracy = correct / total

    return avg_loss, accuracy

# %%
path = '/content/drive/MyDrive/best_recognition_model.pth'
path = '/kaggle/working/best_recognition_model.pth'

def train(model, criterion, optimizer, train_loader, val_loader, num_epochs=100, scheduler=None):
    history = {'train':[],'test':[],'accuracy':[]}
    best_val_loss = float('inf')
    best_accuracy = 0

    for epoch in tqdm(range(num_epochs)):
        train_loss = train_epoch(model, criterion, optimizer, train_loader)
        history['train'].append(train_loss)

        val_loss, accuracy = val_epoch(model, criterion, val_loader)
        history['test'].append(val_loss)
        if scheduler:
          scheduler.step(val_loss)
        print(f"Epoch {epoch + 1} — Train Loss: {train_loss:.4f} — Val Loss: {val_loss:.4f} - Accuracy on val: {accuracy}")

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save(model.state_dict(), path)
            print("✅ Model saved (best so far)")


    return history

# %%
history = train(model, criterion, optimizer, train_loader, val_loader, scheduler=scheduler)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/238 [00:00<?, ?it/s]
# Epoch 1 — Train Loss: 4.3426 — Val Loss: 5.4736 - Accuracy on val: 0.23734781178019085
# ✅ Model saved (best so far)
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/238 [00:00<?, ?it/s]
# Epoch 2 — Train Loss: 3.3432 — Val Loss: 5.1915 - Accuracy on val: 0.2677525501809806
# ✅ Model saved (best so far)
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/238 [00:00<?, ?it/s]
# Epoch 3 — Train Loss: 3.0421 — Val Loss: 5.0203 - Accuracy on val: 0.29355051003619614
# ✅ Model saved (best so far)
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/238 [00:00<?, ?it/s]
# Epoch 4 — Train Loss: 2.8149 — Val Loss: 4.9213 - Accuracy on val: 0.30398157288581773
# ✅ Model saved (best so far)
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/238 [00:00<?, ?it/s]
# Epoch 5 — Train Loss: 2.6133 — Val Loss: 4.8268 - Accuracy on val: 0.322145442579796
# ✅ Model saved (best so far)
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/238 [00:00<?, ?it/s]
# Epoch 6 — Train Loss: 2.4409 — Val Loss: 4.7668 - Accuracy on val: 0.329285949325436
# ✅ Model saved (best so far)
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/238 [00:00<?, ?it/s]
# Epoch 7 — Train Loss: 2.2790 — Val Loss: 4.7116 - Accuracy on val: 0.3379072063178677
# ✅ Model saved (best so far)
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/238 [00:00<?, ?it/s]
# Epoch 8 — Train Loss: 2.1452 — Val Loss: 4.6610 - Accuracy on val: 0.34754853570253375
# ✅ Model saved (best so far)
#   0%|          | 0/950 [00:00<?, ?it/s]
#   0%|          | 0/238 [00:00<?, ?it/s]
# Epoch 9 — Train Loss: 2.0181 — Val Loss: 4.6452 - Accuracy on val: 0.353932214544258
# ✅ Model saved (best so far)
#   0%|          | 0/950 [00:00<?, ?it/s]
